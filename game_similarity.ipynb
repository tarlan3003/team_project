# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

# Load the datasets
games_updated_df = pd.read_csv('Downloads/Games_Updated.csv')
steam_df = pd.read_csv('Downloads/steam.csv')
vgsales_df = pd.read_csv('Downloads/vgsales-2.csv')

# Extract unique game names
games_updated_names = set(games_updated_df['Game_Name'].str.lower())
steam_names = set(steam_df['Game_Name'].str.lower())
vgsales_names = set(vgsales_df['Game_Name'].str.lower())

# Function to remove years from names
def remove_years(name):
    return re.sub(r'\b(19|20)?\d{2}\b', '', name).strip()

# Apply the year removal and collect unique names
all_game_names = list(set(remove_years(name) for name in games_updated_names | steam_names | vgsales_names))

# Vectorize names using TF-IDF
vectorizer = TfidfVectorizer().fit_transform(all_game_names)
cosine_similarities = cosine_similarity(vectorizer)

# Set threshold for similarity
SIMILARITY_THRESHOLD = 0.7  # Cosine similarity threshold

# Identify similar names based on cosine similarity
similar_names = {}
for idx, name in enumerate(all_game_names):
    similar_indices = cosine_similarities[idx] >= SIMILARITY_THRESHOLD
    similar_matches = [all_game_names[i] for i in range(len(all_game_names)) if similar_indices[i] and i != idx]
    if similar_matches:
        similar_names[name] = similar_matches

# Display results
for base_name, matches in list(similar_names.items()):  # Show first 10 matches for readability
    print(f"Base Name: {base_name}")
    print("Similar Names:")
    for match in matches:
        print(f" - {match}")
    print()
# Out:
# Base Name: paladin
# Similar Names:
#  - panzer paladin
#  - flight of the paladin
#
# Base Name: realms of arkania 1 - blade of destiny classic
# Similar Names:
#  - realms of arkania: blade of destiny
#
# Base Name: symphony of stars
# Similar Names:
#  - symphony
#
# Base Name: raw danger
# Similar Names:
#  - raw danger! (jp sales)
#  - raw danger!
#
# Base Name: the rift
# Similar Names:
#  - dark rift
#  - rift
#
# Base Name: evil glitch
# Similar Names:
#  - glitch
#
# Base Name: fate/tiger colosseum upper
# Similar Names:
#  - fate/tiger colosseum
#
# Base Name: metal slug anthology
# Similar Names:
#  - metal slug 7
#  - metal slug 4 & 5
#  - metal slug
#  - metal slug x
#  - metal slug 2
#  - metal slug 3
#
# Base Name: blade arcus from shining ex
# Similar Names:
#  - blade arcus from shining: battle arena
#
# Base Name: victoria ii
# Similar Names:
#  - victoria
#
# Base Name: insane
# Similar Names:
#  - insane robots
#  - insane 2
#  - insane road
#
# Base Name: time
# Similar Names:
#  - time in time
#  - no time
#  - battle time
#
# Base Name: mechassault: phantom war
# Similar Names:
#  - mechassault
#
# Base Name: final storm
# Similar Names:
#  - d.c. s#*!storm
#  - storm
#
# Base Name: romance of the three kingdoms　vi with power up kit / 三國志vi with パワーアップキット
# Similar Names:
#  - romance of the three kingdoms  with power up kit / 三國志12 with パワーアップキット
#  - romance of the three kingdoms ix with power up kit / 三國志ix with パワーアップキット
#  - romance of the three kingdoms ⅳ with power up kit / 三國志ⅳ with パワーアップキット
#  - romance of the three kingdoms　vii with power up kit / 三國志vii with パワーアップキット
#  - romance of the three kingdoms  with power up kit / 三國志11 with パワーアップキット
#  - romance of the three kingdoms ⅴ with power up kit / 三國志ⅴ with パワーアップキット
#  - romance of the three kingdoms x with power up kit / 三國志x with パワーアップキット
#  - romance of the three kingdoms　viii with power up kit / 三國志viii with パワーアップキット
#
# Base Name: sheep raider
# Similar Names:
#  - sheep
#
# Base Name: pdc world championship darts: pro tour
# Similar Names:
#  - pdc world championship darts pro tour
#  - pdc world championship darts
#
# Base Name: friday the 13th: the game
# Similar Names:
#  - friday the 13th: killer puzzle
#
# Base Name: .hack//outbreak part 3
# Similar Names:
#  - .hack part 3: outbreak
#
# Base Name: final fantasy crystal chronicles: the crystal bearers
# Similar Names:
#  - final fantasy: crystal chronicles
#
# Base Name: digimon world 2
# Similar Names:
#  - digimon world 4
#  - digimon world championship
#  - digimon world ds
#  - digimon world 3
#  - digimon world
#
# Base Name: sky tower
# Similar Names:
#  - tower
#
# Base Name: psychic force 2 (import)
# Similar Names:
#  - psychic force
#
# Base Name: espn x-games pro boarder
# Similar Names:
#  - x games pro boarder
#
# Base Name: shining resonance
# Similar Names:
#  - shining resonance refrain
#  - resonance
#
# Base Name: code geass: hangyaku no lelouch r2 - banjou no geass gekijou
# Similar Names:
#  - code geass: hangyaku no lelouch
#
# Base Name: ace attorney investigations 2
# Similar Names:
#  - ace attorney investigations: miles edgeworth
#  - ace attorney 6
#
# Base Name: unknown battle
# Similar Names:
#  - unknown
#
# Base Name: are you smarter than a 5th grader?
# Similar Names:
#  - are you smarter than a 5th grader? back to school
#  - are you smarter than a 5th grader? make the grade
#  - are you smarter than a 5th grader: make the grade
#  - are you smarter than a 5th grader? game time
#
# Base Name: destiny: the collection
# Similar Names:
#  - destiny
#  - destiny 2
#
# Base Name: 3d engineers
# Similar Names:
#  - space engineers
#
# Base Name: steam prison
# Similar Names:
#  - the prison
#
# Base Name: solenars edge rebirth
# Similar Names:
#  - solenars edge heroes
#
# Base Name: ski region simulator
# Similar Names:
#  - ski region simulator - gold edition
#
# Base Name: mummy: tomb of the pharaoh
# Similar Names:
#  - the mummy pharaoh
#
# Base Name: turbo pug dx
# Similar Names:
#  - turbo pug
#  - turbo pug 3d
#
# Base Name: planet r-
# Similar Names:
#  - lost planet 2
#  - lost planet® 2
#  - planet assault
#  - planet alpha : a beautiful planet
#  - lost planet® 3
#  - lost planet 3
#  - planet
#  - metal planet
#
# Base Name: assassin's creed
# Similar Names:
#  - assassin’s creed® brotherhood
#  - assassin's creed® unity
#  - assassin's creed® origins
#  - assassin's creed origins
#  - assassin's creed® syndicate
#  - assassin's creed: brotherhood
#  - assassin's creed ii
#  - assassin's creed 2 deluxe edition
#  - assassin’s creed® rogue
#  - assassin's creed: bloodlines
#  - assassin's creed rogue
#  - assassin's creed syndicate
#  - assassin's creed® revelations
#  - assassin's creed® iii remastered
#  - assassin's creed: rogue
#  - assassin's creed® odyssey
#  - assassin's creed ii: discovery
#  - assassin's creed iii
#  - assassin's creed chronicles
#  - assassin's creed: revelations
#  - assassin's creed: unity
#  - assassin's creed unity
#
# Base Name: heroes of might and magic iii: the shadow of death
# Similar Names:
#  - heroes of might & magic v
#  - heroes of might and magic v
#  - heroes of might and magic
#  - heroes of might and magic iii
#
# Base Name: jade empire™: special edition
# Similar Names:
#  - jade empire: special edition
#  - jade empire
#
# Base Name: grease
# Similar Names:
#  - grease dance
#
# Base Name: world of warcraft: legion
# Similar Names:
#  - world of warcraft
#
# Base Name: fable iii
# Similar Names:
#  - fable
#  - rogue fable iii
#
# Base Name: fruit sudoku🍉 2
# Similar Names:
#  - sudoku
#  - fruit sudoku🍉 3
#  - fruit sudoku🍉
#  - fruit sudoku🍉 4
#
# Base Name: pro yaky? spirits 5
# Similar Names:
#  - pro yaky? spirits
#  - pro yaky? spirits 4
#  - pro yaky? spirits 3
#  - pro yaky? spirits 6
#
# Base Name: long night
# Similar Names:
#  - legend of long night
#
# Base Name: dai-2-ji super robot taisen z: hakai-hen
# Similar Names:
#  - dai-4-ji super robot taisen s
#  - dai-4-ji super robot taisen
#  - dai-2-ji super robot taisen z saisei-hen
#  - dai-2-ji super robot taisen α
#
# Base Name: final fantasy anniversary edition
# Similar Names:
#  - final fantasy
#  - final fantasy v
#  - final fantasy x-2
#  - final fantasy ii: anniversary edition
#  - final fantasy ii anniversary edition
#  - final fantasy x
#
# Base Name: pokemon red/pokemon blue
# Similar Names:
#  - pokemon red
#  - pokemon x/pokemon y
#  - pokemon blue
#  - pokemon x/y
#
# Base Name: conquest of elysium 3
# Similar Names:
#  - conquest of elysium 4
#
# Base Name: rise of nations: extended edition
# Similar Names:
#  - rise of nations
#
# Base Name: battlefield 1
# Similar Names:
#  - board battlefield
#  - battlefield 2
#  - battlefield 3
#  - battlefield 4
#  - battlefield
#
# Base Name: deadly edge
# Similar Names:
#  - deadly
#  - edge
#
# Base Name: inazuma eleven 2: blizzard
# Similar Names:
#  - inazuma eleven 2
#  - inazuma eleven 3
#  - inazuma eleven
#
# Base Name: medal of honor: underground
# Similar Names:
#  - medal of honor
#  - medal of honor heroes 2
#  - medal of honor heroes
#  - medal of honor™
#
# Base Name: sd gundam g generation portable
# Similar Names:
#  - sd gundam g generation
#  - sd gundam g generation ds
#  - sd gundam g generation seed
#  - sd gundam g generation wars
#  - sd gundam g generation: overworld
#  - sd gundam g generation-f.i.f
#  - sd gundam g generation spirits
#  - sd gundam g generation neo
#  - sd gundam g generation world
#  - sd gundam g generation zero
#  - sd gundam g generation 3d
#  - sd gundam g generation-f
#
# Base Name: fushigi no dungeon: fuurai no shiren 3 portable
# Similar Names:
#  - fushigi no dungeon: fuurai no shiren 5 - fortune tower to unmei no dice
#  - fushigi no dungeon: fuurai no shiren gb: tsukikagemura no kaibutsu
#
# Base Name: nidhogg 2
# Similar Names:
#  - nidhogg
#
# Base Name: family party:  great games winter fun
# Similar Names:
#  - family party:  great games
#  - family party:  great games outdoor fun
#
# Base Name: batman - the telltale series: realm of shadows - episode 1
# Similar Names:
#  - batman - the telltale series
#
# Base Name: armorines
# Similar Names:
#  - armorines: project s.w.a.r.m.
#
# Base Name: zup! 4
# Similar Names:
#  - zup! 3
#  - zup! zero 2
#  - zup! x
#  - zup! 6
#  - zup!
#  - zup! s
#  - zup! 8
#  - zup! zero
#  - zup! 2
#  - zup! 5
#  - zup! 7
#  - zup! arena
#
# Base Name: atv offroad fury 4
# Similar Names:
#  - atv offroad fury 3
#  - atv offroad fury
#  - atv offroad fury: blazin' trails
#  - atv offroad fury pro
#  - atv offroad fury 2
#
# Base Name: hentai shooter 3d: christmas party
# Similar Names:
#  - hentai shooter 3d
#
# Base Name: assassin's creed chronicles: china
# Similar Names:
#  - assassin’s creed® chronicles: china
#  - assassin's creed chronicles
#
# Base Name: baseball mogul
# Similar Names:
#  - baseball mogul diamond
#
# Base Name: tales of graces
# Similar Names:
#  - tales of graces f
#
# Base Name: ninja stealth
# Similar Names:
#  - ninja stealth 2
#  - ninja stealth 3
#
# Base Name: pride fc
# Similar Names:
#  - pride fc: fighting championships
#
# Base Name: mega man zx advent
# Similar Names:
#  - mega man zx
#
# Base Name: tekken 5: dark resurrection
# Similar Names:
#  - tekken: dark resurrection
#
# Base Name: black home
# Similar Names:
#  - black home 2
#  - home
#
# Base Name: dungeon raiders
# Similar Names:
#  - the raiders
#
# Base Name: nba jam tournament edition
# Similar Names:
#  - nba jam
#
# Base Name: savage moon
# Similar Names:
#  - savage
#
# Base Name: beasts of bermuda
# Similar Names:
#  - bermuda
#
# Base Name: start the party! save the world
# Similar Names:
#  - start the party
#  - start the party!
#
# Base Name: lostwinds: winter of the melodias
# Similar Names:
#  - lostwinds 2: winter of the melodias
#
# Base Name: towards the pantheon: escaping eternity
# Similar Names:
#  - towards the pantheon
#
# Base Name: tetris worlds (online edition)
# Similar Names:
#  - tetris worlds
#
# Base Name: don't starve together
# Similar Names:
#  - don't starve
#
# Base Name: pain train painpocalypse
# Similar Names:
#  - pain train
#  - pain train 2
#
# Base Name: buffy the vampire slayer: wrath of the darkhul king
# Similar Names:
#  - buffy the vampire slayer
#
# Base Name: derby stallion ii
# Similar Names:
#  - derby stallion iii
#  - derby stallion p
#  - derby stallion advance
#  - derby stallion ds
#  - derby stallion gold
#  - derby stallion
#
# Base Name: boxing
# Similar Names:
#  - boxing saga
#  - boxing apocalypse
#  - boxing school
#  - real boxing™
#
# Base Name: caesars palace
# Similar Names:
#  - caesars palace : millennium gold edition
#  - caesars palace ii
#
# Base Name: my little baby
# Similar Names:
#  - my baby boy
#  - my baby girl
#
# Base Name: shin megami tensei: persona 3
# Similar Names:
#  - shin megami tensei: persona
#  - shin megami tensei iv
#  - shin megami tensei 4: apocalypse
#  - shin megami tensei: persona 3 (jp sales)
#  - shin megami tensei nine
#  - shin megami tensei: persona 2 - innocent sin
#  - shin megami tensei: persona 4
#  - shin megami tensei: persona 3 fes
#  - shin megami tensei: persona 3 portable
#  - shin megami tensei
#  - shin megami tensei: persona 2: innocent sin
#  - shin megami tensei ii
#
# Base Name: black dream
# Similar Names:
#  - dream
#
# Base Name: jade's journey
# Similar Names:
#  - jade's journey 2
#
# Base Name: winning post 8
# Similar Names:
#  - winning post 5
#  - winning post 2
#  - winning post 4
#  - winning post 7: maximum
#  - winning post 7 maximum
#  - winning post world
#  - winning post 6
#  - winning post
#  - winning post / ウイニングポスト
#  - winning post 7
#  - winning post 4 maximum
#  - winning post 3
#
# Base Name: swords and soldiers 2 shawarmageddon
# Similar Names:
#  - swords and soldiers
#  - swords and soldiers 2
#
# Base Name: dance central 3
# Similar Names:
#  - dance central: spotlight
#  - dance central spotlight
#  - dance central 2
#  - dance central
#
# Base Name: fifa: road to the world cup
# Similar Names:
#  - fifa: road to  world cup
#  - project fifa world cup
#  - fifa world cup
#  - fifa : road to fifa world cup
#  - fifa ' - road to the world cup
#  - fifa road to world cup
#  - fifa: road to world cup
#
# Base Name: yu-gi-oh! the sacred cards (jp weekly sales)
# Similar Names:
#  - yu-gi-oh! the sacred cards
#  - yu-gi-oh! the sacred cards (american and others sales)
#
# Base Name: spawn the eternal
# Similar Names:
#  - spawn
#
# Base Name: road trip: the arcade edition
# Similar Names:
#  - road trip
#  - the road trip
#
# Base Name: blazblue: cross tag battle  - the tag team dream
# Similar Names:
#  - blazblue: cross tag battle
#
# Base Name: ding dong xl
# Similar Names:
#  - ding dong vr
#
# Base Name: candy island
# Similar Names:
#  - candy
#
# Base Name: doom & destiny advanced
# Similar Names:
#  - doom & destiny
#
# Base Name: uncharted: golden abyss
# Similar Names:
#  - abyss raiders: uncharted
#
# Base Name: fighting vipers 2
# Similar Names:
#  - fighting vipers
#
# Base Name: rogue port - red nightmare
# Similar Names:
#  - rogue port - blue nightmare
#
# Base Name: cooking mama: world kitchen
# Similar Names:
#  - cooking mama
#  - cooking mama 4: kitchen magic!
#
# Base Name: faerie solitaire
# Similar Names:
#  - faerie solitaire harvest
#  - faerie solitaire remastered
#
# Base Name: mx superfly featuring ricky carmichael
# Similar Names:
#  - mx  featuring ricky carmichael
#
# Base Name: kurt warner's arena football unleashed -
# Similar Names:
#  - kurt warner's arena football unleashed
#
# Base Name: mario party 7
# Similar Names:
#  - mario party
#  - mario party 6
#  - mario party 8
#  - mario party 9
#  - mario party 3
#  - mario party 5
#  - mario party advance
#  - mario party 4
#  - mario party 2
#  - mario party ds
#
# Base Name: dungeon manager zv: resurrection
# Similar Names:
#  - dungeon manager zv 2
#  - dungeon manager zv
#
# Base Name: puzzle & dragons z + super mario bros. edition
# Similar Names:
#  - puzzle & dragons z + puzzle & dragons: super mario bros. edition
#  - super mario bros. 2
#  - super mario bros. 3
#  - super mario bros.
#
# Base Name: ski region simulator - gold edition
# Similar Names:
#  - ski region simulator
#
# Base Name: tony la russa baseball 4
# Similar Names:
#  - tony la russa baseball 3:  edition
#
# Base Name: firefighter f.d.
# Similar Names:
#  - real heroes: firefighter
#
# Base Name: epsilon
# Similar Names:
#  - epsilon corp.
#
# Base Name: deus ex: invisible war
# Similar Names:
#  - deus ex
#
# Base Name: aliens vs. predator™
# Similar Names:
#  - aliens vs. predator
#  - aliens vs. predator 2 - primal hunt
#  - aliens versus predator
#  - aliens vs predator: requiem
#  - aliens vs predator
#  - aliens vs. predator: requiem
#  - aliens versus predator 2
#
# Base Name: volcano eruption
# Similar Names:
#  - eruption
#
# Base Name: geten no hana: yume akari
# Similar Names:
#  - geten no hana
#
# Base Name: carnivores: ice age
# Similar Names:
#  - ice age
#  - ice age 2
#
# Base Name: world's dawn
# Similar Names:
#  - dawn
#  - z dawn
#
# Base Name: the adventures of lomax
# Similar Names:
#  - adventures of lomax
#
# Base Name: jet moto
# Similar Names:
#  - jet moto 3
#  - jet moto 2
#
# Base Name: assassin’s creed® brotherhood
# Similar Names:
#  - assassin's creed
#  - assassin's creed: brotherhood
#
# Base Name: warhammer® ,000: dawn of war® – winter assault
# Similar Names:
#  - warhammer ,000: dawn of war ii
#  - warhammer ,000: dawn of war -- winter assault
#  - warhammer ,000: dawn of war iii
#  - warhammer ,000: dawn of war
#
# Base Name: case 2: animatronics survival
# Similar Names:
#  - case: animatronics
#
# Base Name: a game of thrones - genesis
# Similar Names:
#  - game of thrones
#  - a game of thrones: genesis
#
# Base Name: crash landing
# Similar Names:
#  - ascent: crash landing
#
# Base Name: 100 classic games
# Similar Names:
#  - classic games
#
# Base Name: demon hunter 5: ascendance
# Similar Names:
#  - ascendance
#
# Base Name: bleach: heat the soul 5
# Similar Names:
#  - bleach: heat the soul
#  - bleach: heat the soul 4
#  - bleach: heat the soul 3
#  - bleach: heat the soul 6
#  - bleach: heat the soul 7
#
# Base Name: tasty planet
# Similar Names:
#  - tasty planet forever
#
# Base Name: just cause 3
# Similar Names:
#  - just cause 2
#  - just cause
#  - just cause™ 3
#  - just cause 4
#
# Base Name: survivor vr
# Similar Names:
#  - survivor
#
# Base Name: pipes!
# Similar Names:
#  - pop's pipes
#
# Base Name: jamdat sports mlb
# Similar Names:
#  - jamdat mlb baseball
#
# Base Name: anarchy online: the shadowlands
# Similar Names:
#  - anarchy online
#
# Base Name: aliens versus predator classic
# Similar Names:
#  - aliens versus predator
#  - aliens versus predator: extinction
#  - aliens versus predator 2
#
# Base Name: night fallen
# Similar Names:
#  - fallen
#
# Base Name: l.g.s: shinsetsu houshinengi
# Similar Names:
#  - houshinengi
#
# Base Name: tokimeki memorial: girls side 1st love
# Similar Names:
#  - tokimeki memorial girl's side 1st love plus
#
# Base Name: the labyrinth of time
# Similar Names:
#  - the labyrinth
#  - labyrinth
#
# Base Name: time virus
# Similar Names:
#  - virus
#  - virus z
#
# Base Name: frontlines™: fuel of war™
# Similar Names:
#  - frontlines: fuel of war
#
# Base Name: godzilla: unleashed
# Similar Names:
#  - godzilla unleashed: double smash
#  - godzilla
#  - godzilla unleashed
#  - godzilla ()
#
# Base Name: roll away
# Similar Names:
#  - roll!
#  - roll'd
#  - away
#
# Base Name: dungeon hero
# Similar Names:
#  - hero
#  - hero-e
#  - hero x
#
# Base Name: negligee: love stories
# Similar Names:
#  - negligee
#
# Base Name: saboteur!
# Similar Names:
#  - the saboteur
#
# Base Name: total war: medieval ii – definitive edition
# Similar Names:
#  - medieval ii: total war gold edition
#  - medieval ii: total war™ kingdoms
#  - medieval 2: total war
#  - medieval: total war
#  - medieval ii: total war kingdoms
#  - medieval ii: total war
#  - total war: empire – definitive edition
#
# Base Name: damsel
# Similar Names:
#  - knight & damsel
#
# Base Name: shining in the darkness
# Similar Names:
#  - in darkness
#
# Base Name: acceleration of suguri x edition
# Similar Names:
#  - acceleration of suguri 2
#  - acceleration of suguri x-edition hd
#
# Base Name: silent hunter
# Similar Names:
#  - silent hunter® iii
#  - silent hunter ii
#  - silent hunter iii
#
# Base Name: guitar hero: warriors of rock
# Similar Names:
#  - guitar hero 5
#  - guitar hero iii: legends of rock
#  - guitar hero
#
# Base Name: evil orbs
# Similar Names:
#  - orbs
#
# Base Name: brick breaker bunch
# Similar Names:
#  - brick breaker
#
# Base Name: nba 2k playgrounds 2  - ball another day
# Similar Names:
#  - nba 2k playgrounds 2
#
# Base Name: outcast
# Similar Names:
#  - outcast 1.1
#
# Base Name: game builder
# Similar Names:
#  - smile game builder
#  - world builder
#
# Base Name: anime bubble pop
# Similar Names:
#  - super bubble pop
#
# Base Name: the movies
# Similar Names:
#  - disney movies vr
#  - attack of the movies 3d
#
# Base Name: privateers
# Similar Names:
#  - pixel privateers
#
# Base Name: dead island: riptide definitive edition
# Similar Names:
#  - dead island: riptide
#  - dead island definitive edition
#
# Base Name: jak 3
# Similar Names:
#  - jak ii
#  - jak x: combat racing
#
# Base Name: the fast and the furious
# Similar Names:
#  - 2 fast 2 furious
#  - fast & furious: showdown
#  - dragon ball fighterz : the fast and the furious
#
# Base Name: feel the magic: xy/xx
# Similar Names:
#  - feel the magic xy/xx
#
# Base Name: spelunky
# Similar Names:
#  - spelunky!
#
# Base Name: pokemon leafgreen
# Similar Names:
#  - pokemon firered/pokemon leafgreen
#
# Base Name: eldritch
# Similar Names:
#  - eldritch hunter
#  - eldritch academy
#
# Base Name: the perfect unit
# Similar Names:
#  - unit
#  - unit 4
#
# Base Name: sonic & sega all-stars racing
# Similar Names:
#  - sonic & sega all-stars racing with banjo-kazooie
#
# Base Name: dead or alive 6  - combat ready
# Similar Names:
#  - dead or alive 4
#  - dead or alive 6
#  - dead or alive 2
#  - dead or alive 3
#  - dead or alive 5
#  - dead or alive
#
# Base Name: age of empires iii: gold edition
# Similar Names:
#  - age of empires iii
#  - age of empires
#
# Base Name: hero of the kingdom
# Similar Names:
#  - hero of the kingdom ii
#  - hero of the kingdom iii
#
# Base Name: ＜/reality＞
# Similar Names:
#  - reality fighters
#  - broken reality
#  - reality
#  - beyond reality
#
# Base Name: princess isabella - return of the curse
# Similar Names:
#  - princess isabella
#  - princess isabella: a witch's curse
#
# Base Name: tanks
# Similar Names:
#  - tiny tanks
#  - infinite tanks
#  - tanks!!!
#  - tanks vr
#  - cats tanks
#  - world of tanks
#
# Base Name: wrecked destruction simulator
# Similar Names:
#  - wrecked
#
# Base Name: slice&dice
# Similar Names:
#  - slice, dice & rice
#
# Base Name: gunman clive 2
# Similar Names:
#  - gunman clive
#
# Base Name: micro miners
# Similar Names:
#  - the miners
#
# Base Name: motocross madness
# Similar Names:
#  - motocross madness 2
#
# Base Name: prince of persia
# Similar Names:
#  - prince of persia trilogy
#  - prince of persia®
#  - battles of prince of persia
#  - prince of persia revelations
#  - prince of persia classic
#  - prince of persia: sands of time
#  - prince of persia: warrior within
#  - prince of persia: the sands of time
#  - prince of persia®: the sands of time
#  - prince of persia: the two thrones
#  - prince of persia: the fallen king
#  - prince of persia 3d
#  - prince of persia: warrior within™
#  - prince of persia: the two thrones™
#  - prince of persia ()
#  - prince of persia: revelations
#
# Base Name: teenage mutant ninja turtles double pack
# Similar Names:
#  - teenage mutant ninja turtles: arcade attack
#  - teenage mutant ninja turtles
#  - teenage mutant ninja turtles 2
#  - teenage mutant ninja turtles 3: mutant nightmare
#  - teenage mutant ninja turtles (3ds)
#  - teenage mutant ninja turtles: tournament fighters
#  - teenage mutant ninja turtles ii: the arcade game
#  - teenage mutant ninja turtles 2: battle nexus
#  - teenage mutant ninja turtles: smash-up
#
# Base Name: dai-4-ji super robot taisen s
# Similar Names:
#  - dai-2-ji super robot taisen z: hakai-hen
#  - dai-3-ji super robot taisen α: shuuen no ginga e
#  - dai-2-ji super robot taisen og
#  - dai-4-ji super robot taisen
#  - dai-2-ji super robot taisen z saisei-hen
#  - dai-2-ji super robot taisen α
#
# Base Name: hot shots golf: open tee 2
# Similar Names:
#  - hot shots golf 3
#  - hot shots golf 2
#  - hot shots golf
#  - hot shots golf: open tee
#
# Base Name: sonic pinball party
# Similar Names:
#  - sonic advance & sonic pinball party combo pack
#
# Base Name: forge
# Similar Names:
#  - lantern forge
#  - gem forge
#
# Base Name: test drive off-road
# Similar Names:
#  - test drive: off-road
#  - test drive: off-road 3
#  - test drive
#  - off-road drive
#  - test drive 6
#  - test drive: off road
#  - test drive: off-road 2
#  - test drive off-road wide open
#  - test drive 5
#  - test drive 4
#
# Base Name: airline tycoon 2
# Similar Names:
#  - airline tycoon deluxe
#  - airline tycoon
#  - airline director 2 - tycoon game
#
# Base Name: disney's brother bear
# Similar Names:
#  - 2 games in 1: disney's brother bear / the lion king 1 1/2
#
# Base Name: ripple
# Similar Names:
#  - ripple effect
#
# Base Name: hakuouki: zuisouroku portable
# Similar Names:
#  - hakuouki: zuisouroku
#  - hakuouki portable
#  - hakuouki: zuisouroku ds
#
# Base Name: cool boarders 3
# Similar Names:
#  - cool boarders 4
#  - cool boarders 2
#  - cool boarders
#
# Base Name: legend of dragoon
# Similar Names:
#  - the legend of dragoon
#
# Base Name: operation lone wolf
# Similar Names:
#  - lone wolf: horizon
#
# Base Name: color by number - pixel draw
# Similar Names:
#  - pixel art monster - color by number
#
# Base Name: gump runner
# Similar Names:
#  - gump
#
# Base Name: the settlers: rise of an empire gold edition
# Similar Names:
#  - the settlers: rise of an empire
#  - the settlers® : rise of an empire - history edition
#
# Base Name: the hobbit
# Similar Names:
#  - lego the hobbit
#
# Base Name: call of duty®: advanced warfare - gold edition
# Similar Names:
#  - call of duty: advanced warfare
#
# Base Name: franchise hockey manager 3
# Similar Names:
#  - franchise hockey manager 5
#  - franchise hockey manager 4
#
# Base Name: farm frenzy 3
# Similar Names:
#  - farm frenzy: pizza party
#  - farm frenzy collection
#  - farm frenzy 2
#  - farm frenzy 4
#  - farm frenzy
#
# Base Name: chainsaw warrior: lords of the night
# Similar Names:
#  - chainsaw warrior
#
# Base Name: dora the explorer: dora saves the mermaids
# Similar Names:
#  - dora the explorer: dora saves the crystal kingdom
#  - dora the explorer: dora puppy
#  - dora the explorer: dora saves the snow princess
#
# Base Name: half-minute hero: super mega neo climax
# Similar Names:
#  - half minute hero: super mega neo climax ultimate boy
#
# Base Name: super dodgeball brawlers
# Similar Names:
#  - super dodgeball brawlers (jp sales)
#
# Base Name: the secret of monkey island: special edition
# Similar Names:
#  - monkey island: special edition collection
#
# Base Name: ninja gaiden 3
# Similar Names:
#  - ninja gaiden
#  - yaiba: ninja gaiden z
#  - ninja gaiden sigma
#  - ninja gaiden black
#  - ninja gaiden: dragon sword
#  - ninja gaiden ii
#  - ninja gaiden volume 1: destiny
#  - ninja gaiden sigma 2
#  - ninja gaiden dragon sword
#
# Base Name: mirror mysteries 2
# Similar Names:
#  - mirror
#  - mirror mysteries
#
# Base Name: pokemon rumble world
# Similar Names:
#  - pokemon rumble blast
#
# Base Name: bridge constructor medieval
# Similar Names:
#  - bridge constructor
#
# Base Name: sakura fantasy
# Similar Names:
#  - sakura sakura
#
# Base Name: disney epic mickey: power of illusion
# Similar Names:
#  - epic mickey: power of illusion
#  - disney epic mickey 2:  the power of two
#  - disney epic mickey
#
# Base Name: painkiller redemption
# Similar Names:
#  - painkiller
#
# Base Name: king of clubs
# Similar Names:
#  - king of clubs: mini golf
#
# Base Name: no crossing
# Similar Names:
#  - crossing man
#
# Base Name: gothic universe
# Similar Names:
#  - gothic® 3
#  - gothic 1
#  - gothic 3
#  - gothic
#
# Base Name: magical drop v
# Similar Names:
#  - magical drop f (import)
#
# Base Name: our house party!
# Similar Names:
#  - house party
#  - our house
#
# Base Name: neko-nin exheart 2
# Similar Names:
#  - neko-nin exheart +plus saiha
#  - neko-nin exheart +plus nachi
#  - neko-nin exheart
#
# Base Name: space cat
# Similar Names:
#  - space jump cat
#
# Base Name: silence
# Similar Names:
#  - the magical silence
#  - time of silence
#  - deadly silence
#
# Base Name: f- lightning ii
# Similar Names:
#  - lightning war
#  - f- lightning 3
#
# Base Name: pizza connection
# Similar Names:
#  - pizza connection 3
#  - pizza connection 2
#
# Base Name: book series - alice in wonderland
# Similar Names:
#  - alice in wonderland
#  - disney alice in wonderland
#
# Base Name: city rush
# Similar Names:
#  - l.a. rush
#  - c-rush
#  - rush
#
# Base Name: mega man battle network 5: team protoman
# Similar Names:
#  - mega man battle network 3
#  - mega man battle network 2
#  - mega man battle network
#  - mega man battle network 5: double team
#  - mega man battle network 5: team colonel / protoman
#
# Base Name: lovers ' smiles
# Similar Names:
#  - lovers ' smiles 2
#
# Base Name: √letter - root letter -
# Similar Names:
#  - the last letter
#  - love letter
#
# Base Name: star trek: deep space nine: dominion wars
# Similar Names:
#  - star trek: deep space nine: the fallen
#
# Base Name: achievement idler: black
# Similar Names:
#  - achievement idler: red
#
# Base Name: dragon age: origins - ultimate edition
# Similar Names:
#  - dragon age: origins
#
# Base Name: cally's caves 3
# Similar Names:
#  - cally's caves 4
#
# Base Name: naruto shippuden: gekito ninja taisen! ex 2
# Similar Names:
#  - naruto: gekito ninja taisen! 3
#  - naruto shippuden: gekito ninja taisen! special
#  - naruto: gekito ninja taisen! 4
#  - naruto shippuden: gekito ninja taisen! ex
#  - naruto shippuden: gekito ninja taisen! ex 3
#
# Base Name: gigantic army
# Similar Names:
#  - gigantic
#
# Base Name: revelations
# Similar Names:
#  - resident evil revelations / biohazard revelations
#  - resident evil revelations 2 / biohazard revelations 2
#
# Base Name: no safety
# Similar Names:
#  - safety first!
#
# Base Name: bee aware!
# Similar Names:
#  - aware
#
# Base Name: tetris splash
# Similar Names:
#  - splash
#
# Base Name: yu-gi-oh! gx: the beginning of destiny (jp sales)
# Similar Names:
#  - yu-gi-oh! gx: the beginning of destiny (us sales)
#
# Base Name: total war: warhammer 2
# Similar Names:
#  - total war: warhammer ii
#  - total war: warhammer
#
# Base Name: socom: u.s. navy seals fireteam bravo 2
# Similar Names:
#  - socom fireteam bravo
#  - socom ii: u.s. navy seals
#  - socom: u.s. navy seals
#  - socom 4: u.s. navy seals
#  - socom 3: u.s. navy seals
#  - socom: u.s. navy seals fireteam bravo 3
#  - socom: u.s. navy seals fireteam bravo
#
# Base Name: pro yakyuu famista
# Similar Names:
#  - pro yakyuu famista ds
#
# Base Name: storm lover 2nd v
# Similar Names:
#  - storm lover 2nd
#
# Base Name: second ninja
# Similar Names:
#  - second ninja x
#  - second second
#
# Base Name: box maze extreme
# Similar Names:
#  - box maze
#
# Base Name: serious sam advance
# Similar Names:
#  - serious sam ii
#  - serious sam 2
#  - serious sam
#
# Base Name: new super mario bros. u
# Similar Names:
#  - new super mario bros.
#  - new super mario bros. 2
#  - super mario advance 4: super mario bros. 3
#  - super mario bros. 2
#  - mario bros.
#  - super mario bros.   – mario royale
#  - super mario bros. 3
#  - super mario bros.
#  - new super mario bros. wii
#
# Base Name: you don't know jack: mock 2
# Similar Names:
#  - you don't know jack volume 2
#  - you don't know jack
#  - you don't know jack ()
#  - you don't know jack vol. 3
#  - you don't know jack vol. 2
#  - you don't know jack: the ride
#  - you don't know jack sports
#  - you don't know jack volume 3
#
# Base Name: mind shift 🔲
# Similar Names:
#  - shift
#
# Base Name: rock 'n roll
# Similar Names:
#  - roll!
#  - rock 'n' roll defense
#  - rock 'n roll racing
#  - rock 'n' roll adventures
#  - roll'd
#  - rock n' roll racing
#
# Base Name: pro yakyuu netsu star
# Similar Names:
#  - netsu chu! pro yakyuu
#
# Base Name: warriors orochi 4 - 無双orochi３
# Similar Names:
#  - warriors orochi 2
#  - warriors orochi 3
#  - warriors orochi
#
# Base Name: crayon shin-chan shokkugan! densetsu o yobu omake daiketsusen!!
# Similar Names:
#  - crayon shin-chan: densetsu o yobu omake no to shukkugaan!
#
# Base Name: medal of honor
# Similar Names:
#  - medal of honor: underground
#  - medal of honor heroes 2
#  - medal of honor rising sun
#  - medal of honor frontline
#  - medal of honor: infiltrator
#  - medal of honor pacific assault
#  - medal of honor european assault
#  - medal of honor infiltrator
#  - medal of honor: rising sun
#  - medal of honor: frontline
#  - medal of honor: european assault
#  - medal of honor heroes
#  - medal of honor™
#  - medal of honor: airborne
#  - medal of honor: vanguard
#  - medal of honor: allied assault
#  - medal of honor: warfighter
#
# Base Name: battle pixels
# Similar Names:
#  - dead pixels
#
# Base Name: mountain king
# Similar Names:
#  - mountain
#
# Base Name: platypus
# Similar Names:
#  - platypus ii
#
# Base Name: naruto shippuden: ultimate ninja heroes 3
# Similar Names:
#  - naruto shippuden: ninja destiny 3
#  - naruto shippuden: ultimate ninja impact
#  - naruto shippuden: ultimate ninja storm collection
#  - naruto shippuden: ultimate ninja storm 2
#  - naruto shippuden: ninja destiny 2
#  - naruto shippuden: ultimate ninja 4
#  - naruto shippuden: ultimate ninja storm generations
#  - naruto shippuden: ultimate ninja storm 4
#  - naruto: ultimate ninja 3
#  - naruto: ultimate ninja heroes
#  - naruto shippuden: ultimate ninja 5
#  - naruto: ultimate ninja 2
#  - naruto: ultimate ninja
#  - naruto shippuden: ultimate ninja storm revolution
#  - naruto shippuden: ultimate ninja storm 3
#
# Base Name: stronghold legends
# Similar Names:
#  - stronghold legends: steam edition
#  - stronghold 3
#  - stronghold 2
#  - stronghold
#
# Base Name: stolen song
# Similar Names:
#  - stolen
#
# Base Name: domino sky
# Similar Names:
#  - domino vr
#  - domino
#
# Base Name: hunter x hunter: wonder adventure
# Similar Names:
#  - hunter
#
# Base Name: the king of fighters : unlimited match
# Similar Names:
#  - the king of fighters ' global match
#  - the king of fighters ' ultimate match
#  - the king of fighters: dream match
#  - king of fighters : unlimited match tougeki ver.
#  - king of fighters dream match
#  - the king of fighters  unlimited match
#
# Base Name: from tv animation one piece: treasure battle!
# Similar Names:
#  - from tv animation one piece: grand battle 2
#  - from tv animation one piece: grand battle! 3
#
# Base Name: choice chamber
# Similar Names:
#  - chamber
#
# Base Name: serious sam: the first encounter
# Similar Names:
#  - serious sam: next encounter
#  - serious sam vr: the first encounter
#  - serious sam vr: the second encounter
#  - serious sam: the random encounter
#  - serious sam: the second encounter
#  - serious sam hd: the first encounter
#  - serious sam 2
#  - serious sam
#  - serious sam 4  – the fourth encounter
#  - serious sam hd: the second encounter
#
# Base Name: lego® the incredibles
# Similar Names:
#  - the incredibles
#
# Base Name: karaoke revolution glee 2: road to regionals
# Similar Names:
#  - karaoke revolution glee
#
# Base Name: ninja gaiden
# Similar Names:
#  - ninja gaiden 3
#  - yaiba: ninja gaiden z
#  - ninja gaiden sigma
#  - ninja gaiden black
#  - ninja gaiden: dragon sword
#  - ninja gaiden ii
#  - ninja gaiden volume 1: destiny
#  - ninja gaiden sigma 2
#  - ninja gaiden dragon sword
#
# Base Name: battle arena toshinden
# Similar Names:
#  - battle arena toshinden 3
#  - battle arena toshinden 2
#  - battle arena toshinden remix
#  - battle arena toshinden ura
#
# Base Name: singularity roller
# Similar Names:
#  - singularity™
#  - singularity
#  - singularity 5
#
# Base Name: epic mickey: power of illusion
# Similar Names:
#  - disney epic mickey: power of illusion
#  - epic mickey 2: the power of two
#  - epic mickey
#
# Base Name: fantastic four
# Similar Names:
#  - fantastic 4
#
# Base Name: alpine ski vr
# Similar Names:
#  - tahko alpine ski
#
# Base Name: risk: global domination
# Similar Names:
#  - global domination
#
# Base Name: chip's challenge 2
# Similar Names:
#  - chip's challenge 1
#  - mega man battle chip challenge
#  - chip's challenge
#  - chip
#
# Base Name: virtua striker
# Similar Names:
#  - virtua striker 2
#  - striker
#
# Base Name: warlords
# Similar Names:
#  - warlords awakening
#
# Base Name: top spin 2
# Similar Names:
#  - top spin 3
#  - top spin
#  - top spin tennis
#  - top spin 4
#
# Base Name: the sky climber
# Similar Names:
#  - the climber
#
# Base Name: super arcade soccer
# Similar Names:
#  - super soccer
#
# Base Name: steel soldiers
# Similar Names:
#  - z steel soldiers
#
# Base Name: super street fighter iv
# Similar Names:
#  - street fighter 5
#  - ultra street fighter® iv
#  - super street fighter iv arcade edition
#  - street fighter® iv
#  - ultra street fighter iv
#  - super street fighter iv: 3d edition
#  - street fighter iv
#  - super street fighter ii
#  - street fighter v
#
# Base Name: the enthralling realms: an alchemist's tale
# Similar Names:
#  - the enthralling realms
#
# Base Name: cool boarders 4
# Similar Names:
#  - cool boarders 3
#  - cool boarders 2
#  - cool boarders
#
# Base Name: phoenix wright: ace attorney - dual destinies
# Similar Names:
#  - phoenix wright: ace attorney
#  - phoenix wright: ace attorney trilogy
#
# Base Name: bloodrayne 2
# Similar Names:
#  - bloodrayne
#  - bloodrayne: betrayal
#  - bloodrayne betrayal
#
# Base Name: virus: the game
# Similar Names:
#  - virus
#  - virus z
#
# Base Name: destroyer command
# Similar Names:
#  - destroyer
#
# Base Name: kingdom hearts: chain of memories
# Similar Names:
#  - kingdom hearts re: chain of memories
#
# Base Name: monster rpg 3
# Similar Names:
#  - monster rpg 2
#
# Base Name: station  - space station simulator
# Similar Names:
#  - space station alpha
#  - vr escape the space station
#  - escape station
#  - the station
#  - train station simulator
#
# Base Name: wrc: fia world rally championship
# Similar Names:
#  - wrc: world rally championship
#  - wrc 6 fia world rally championship
#  - wrc 2: fia world rally championship
#  - wrc 7 fia world rally championship
#  - wrc 4 fia world rally championship
#  - wrc 4: fia world rally championship
#  - wrc 5 fia world rally championship
#  - wrc 5: fia world rally championship
#
# Base Name: tago akira no atama no taisou dai-1-shuu: nazotoki sekai isshuu ryokou
# Similar Names:
#  - tago akira no atama no taisou dai-2-shuu: ginga oudan nazotoki adventure
#
# Base Name: snow
# Similar Names:
#  - dark snow
#  - snow fall
#  - tiny snow
#  - snow horse
#  - snow fortress
#  - snow light
#  - snow games vr
#  - snow portable
#
# Base Name: ballistic tanks
# Similar Names:
#  - ballistic
#
# Base Name: dead or alive 4
# Similar Names:
#  - dead or alive 6  - combat ready
#  - dead or alive 6
#  - dead or alive paradise
#  - dead or alive 2
#  - dead or alive xtreme 3: fortune
#  - dead or alive xtreme 2
#  - dead or alive 3
#  - dead or alive 5
#  - dead or alive: dimensions
#  - dead or alive 2: hardcore
#  - dead or alive
#  - dead or alive ultimate
#  - dead or alive (import)
#
# Base Name: higurashi when they cry hou - ch.6 tsumihoroboshi
# Similar Names:
#  - higurashi when they cry hou - ch.2 watanagashi
#  - higurashi when they cry hou - ch.1 onikakushi
#  - higurashi when they cry hou - ch. 5 meakashi
#  - higurashi when they cry hou - ch.3 tatarigoroshi
#  - higurashi when they cry hou - ch.4 himatsubushi
#
# Base Name: tank
# Similar Names:
#  - tank game
#  - death tank
#  - tank beat
#  - tank assault x
#  - tank rush
#  - tank souls
#  - tank battles
#  - tank force
#  - tank on tank digital  - west front
#  - tank battle:
#  - tank! tank! tank!
#  - tank blast
#
# Base Name: echochrome
# Similar Names:
#  - echochrome ii
#
# Base Name: final fantasy iv
# Similar Names:
#  - final fantasy
#  - final fantasy v
#  - final fantasy iv: the complete collection
#  - final fantasy x-2
#  - final fantasy iv advance
#  - final fantasy x
#  - final fantasy iv (import)
#
# Base Name: shadowrun: hong kong - extended edition
# Similar Names:
#  - shadowrun: hong kong
#
# Base Name: wwe raw 2
# Similar Names:
#  - wwe smackdown vs raw
#  - wwe raw
#  - wwe smackdown vs. raw
#  - wwe smackdown! vs. raw
#
# Base Name: tank game
# Similar Names:
#  - tank
#  - tank! tank! tank!
#
# Base Name: prince of persia trilogy
# Similar Names:
#  - prince of persia
#  - prince of persia®
#  - battles of prince of persia
#  - prince of persia classic
#  - prince of persia 3d
#  - prince of persia ()
#
# Base Name: chocolate makes you happy 2
# Similar Names:
#  - chocolate makes you happy: new year
#  - chocolate makes you happy: lunar new year
#  - chocolate makes you happy: st.patrick's day
#  - chocolate makes you happy: halloween
#  - chocolate makes you happy 4
#  - chocolate makes you happy 3
#  - chocolate makes you happy 7
#  - chocolate makes you happy 6
#  - chocolate makes you happy
#  - chocolate makes you happy 5
#  - chocolate makes you happy: valentine's day
#
# Base Name: a way up!
# Similar Names:
#  - way-z
#  - l-way
#
# Base Name: carmageddon 3: tdr
# Similar Names:
#  - carmageddon tdr
#
# Base Name: silhouette
# Similar Names:
#  - silhouette mirage
#
# Base Name: magic  — duels of the planeswalkers
# Similar Names:
#  - magic duels
#  - magic: the gathering duels of the planeswalkers
#  - magic  - duels of the planeswalkers
#  - magic the gathering - duels of the planeswalkers
#  - magic: the gathering - duels of the planeswalkers
#
# Base Name: maplestory 2
# Similar Names:
#  - maplestory
#  - maplestory ds
#
# Base Name: glitch's trip
# Similar Names:
#  - glitch
#
# Base Name: dance dance revolution: hottest party 3
# Similar Names:
#  - dance dance revolution universe 3
#  - dance dance revolution extreme 2
#  - dance dance revolution extreme
#  - dance dance revolution x
#  - dance dance revolution hottest party
#  - dance dance revolution: hottest party 2
#  - dance dance revolution (import)
#  - dance dance revolution universe 2
#  - dance dance revolution
#  - dance dance revolution universe
#  - dance dance revolution: hottest party 5
#  - dance dance revolution: hottest party
#
# Base Name: super robot taisen ux
# Similar Names:
#  - super robot taisen k
#  - super robot taisen z
#  - super robot taisen f
#  - super robot taisen l
#  - super robot taisen a
#  - super robot taisen
#  - super robot taisen α
#  - super robot taisen d
#  - super robot taisen j
#  - super robot taisen w
#  - super robot taisen r
#
# Base Name: wii play
# Similar Names:
#  - wii play: motion
#
# Base Name: starship titanic
# Similar Names:
#  - titanic
#
# Base Name: solar war
# Similar Names:
#  - blue solar: chaos war
#  - solar 2
#
# Base Name: silent scope complete
# Similar Names:
#  - silent scope 3
#  - silent scope
#
# Base Name: final fantasy
# Similar Names:
#  - final fantasy anniversary edition
#  - final fantasy iv
#  - final fantasy v advance
#  - final fantasy v
#  - final fantasy iii
#  - final fantasy x-2
#  - final fantasy xiii
#  - world of final fantasy®
#  - final fantasy® xiii-2
#  - final fantasy anthology
#  - final fantasy adventure
#  - final fantasy® xiii
#  - final fantasy xiii-2
#  - final fantasy origins
#  - final fantasy tactics
#  - the final fantasy legend
#  - final fantasy chronicles
#  - final fantasy collection
#  - final fantasy x
#  - final fantasy vii
#  - final fantasy legend iii
#  - final fantasy x international
#  - final fantasy vi
#  - world of final fantasy
#  - final fantasy type-0
#  - final fantasy i & ii
#  - final fantasy ii
#  - final fantasy xi
#
# Base Name: bloom
# Similar Names:
#  - bloom: labyrinth
#
# Base Name: the gameshow
# Similar Names:
#  - family gameshow
#
# Base Name: final soccer vr
# Similar Names:
#  - vr soccer '
#  - vr soccer
#
# Base Name: the sims deluxe
# Similar Names:
#  - the sims 2
#  - the sims 4
#  - the sims
#  - the sims 3
#  - the sims™ 3
#
# Base Name: rolling thunder 2
# Similar Names:
#  - blitzkrieg: rolling thunder
#
# Base Name: guitar freaks append 2nd mix (import)
# Similar Names:
#  - guitar freaks 3rd mix & drummania 2nd mix import
#
# Base Name: mario party
# Similar Names:
#  - mario party 7
#  - mario party 6
#  - mario party 8
#  - mario party 9
#  - mario party 3
#  - mario party 5
#  - mario party advance
#  - mario party 4
#  - mario party 2
#  - mario party ds
#
# Base Name: shadow complex
# Similar Names:
#  - shadow complex remastered
#
# Base Name: america's army 3
# Similar Names:
#  - america
#  - america's army: rise of a soldier
#  - america's army: operations
#
# Base Name: shin nippon pro wrestling: toukon retsuden
# Similar Names:
#  - shin nippon pro wrestling: toukon retsuden 2
#  - shin nippon pro wrestling: toukon retsuden 3
#
# Base Name: clicker: glad valakas
# Similar Names:
#  - glad valakas simulator
#
# Base Name: guitar hero 5
# Similar Names:
#  - guitar hero: warriors of rock
#  - guitar hero live
#  - guitar hero world tour
#  - guitar hero: world tour
#  - guitar hero: on tour
#  - guitar hero ii
#  - guitar hero
#
# Base Name: track & field
# Similar Names:
#  - new international track & field
#  - international track & field
#  - espn international track & field
#  - fox sports track and field '
#  - international track and field
#
# Base Name: colony assault
# Similar Names:
#  - colony
#  - the colony
#
# Base Name: doki-doki universe
# Similar Names:
#  - doki doki! precure narikiri life!
#  - tamagotchi no doki doki dream omisecchi
#  - doki doki literature club!
#
# Base Name: mag force racing
# Similar Names:
#  - mag
#
# Base Name: fox & flock
# Similar Names:
#  - flock
#  - flock!
#  - the flock
#
# Base Name: ai dummy
# Similar Names:
#  - dummy!
#
# Base Name: infinity escape
# Similar Names:
#  - infinity
#
# Base Name: deadly kingdom
# Similar Names:
#  - deadly
#
# Base Name: trivia vault: business trivia
# Similar Names:
#  - trivia vault: toy trivia
#  - trivia vault: mini mixed trivia 3
#  - trivia vault: boxing trivia
#  - trivia vault: tv trivia
#  - trivia vault: science & history trivia
#  - trivia vault: soccer trivia
#  - trivia vault football trivia
#  - trivia vault olympics trivia
#  - trivia vault: art trivia
#  - trivia vault: mixed trivia
#  - trivia vault: technology trivia deluxe
#  - trivia vault: mixed trivia 2
#  - trivia vault: mini mixed trivia
#  - trivia vault: movie trivia
#  - trivia vault: 's trivia
#  - trivia vault: 's trivia 2
#  - trivia vault: fashion trivia
#  - trivia vault: food trivia
#  - trivia vault: health trivia deluxe
#  - trivia vault: literature trivia
#  - trivia vault: auto racing trivia
#  - trivia vault: classic rock trivia
#  - trivia vault: mini mixed trivia 2
#  - trivia vault: celebrity trivia
#  - trivia vault: hockey trivia
#  - trivia vault: super heroes trivia
#  - trivia vault: science & history trivia 2
#  - trivia vault: music trivia
#  - trivia vault: golf trivia
#  - trivia vault baseball trivia
#  - trivia vault: video game trivia deluxe
#  - trivia vault: mini mixed trivia 4
#  - trivia vault basketball trivia
#  - trivia vault: super heroes trivia 2
#  - trivia vault: classic rock trivia 2
#  - trivia vault: tennis trivia
#
# Base Name: tactics ogre
# Similar Names:
#  - ogre
#  - ogre battle series: tactics ogre
#
# Base Name: project gotham racing 2
# Similar Names:
#  - project gotham racing 4
#  - project gotham racing
#  - pgr: project gotham racing 2
#  - project gotham racing 3
#  - pgr4 - project gotham racing 4
#  - pgr3 - project gotham racing 3
#
# Base Name: zhuzhu pets: featuring the wild bunch
# Similar Names:
#  - zhuzhu pets 2: featuring the wild bunch
#
# Base Name: super mario galaxy
# Similar Names:
#  - super mario galaxy 2
#  - super mario
#
# Base Name: mirage
# Similar Names:
#  - mirage of dragon
#
# Base Name: metroid prime 3: corruption
# Similar Names:
#  - metroid prime
#
# Base Name: frogger: the great quest
# Similar Names:
#  - frogger advance: the great quest
#
# Base Name: snails
# Similar Names:
#  - epic snails
#
# Base Name: antz extreme racing
# Similar Names:
#  - antz
#
# Base Name: cities: skylines snowfall
# Similar Names:
#  - cities: skylines
#
# Base Name: toukon retsuden 3 (import)
# Similar Names:
#  - toukon retsuden 2 (import)
#
# Base Name: the new york times crosswords
# Similar Names:
#  - new york times crosswords
#
# Base Name: chip's challenge 1
# Similar Names:
#  - chip's challenge 2
#  - mega man battle chip challenge
#  - chip's challenge
#  - chip
#
# Base Name: akin
# Similar Names:
#  - akin vol 2
#
# Base Name: f1
# Similar Names:
#  - f1 race
#  - f1 challenge
#  - f1 ™
#  - f1™
#  - f1 challenge '-'
#  - power f1
#
# Base Name: national treasure
# Similar Names:
#  - the division 2  - national treasure
#  - national treasure puzzle quest
#
# Base Name: the bard's tale iv: barrows deep
# Similar Names:
#  - the bard's tale iv: barrows deep  - lament
#
# Base Name: doki doki! precure narikiri life!
# Similar Names:
#  - doki-doki universe
#
# Base Name: that's so raven
# Similar Names:
#  - that's so raven: psychic on the scene
#  - that's so raven 2: supernatural style
#
# Base Name: gal*gun: double peace
# Similar Names:
#  - gal*gun 2
#  - gal gun: double peace
#  - gal gun
#  - gal*gun
#
# Base Name: littlebigplanet 2
# Similar Names:
#  - littlebigplanet 3
#  - littlebigplanet
#
# Base Name: socom: u.s. navy seals confrontation
# Similar Names:
#  - socom ii: u.s. navy seals
#  - socom: u.s. navy seals
#  - socom 4: u.s. navy seals
#  - socom 3: u.s. navy seals
#
# Base Name: the revenge of johnny bonasera: episode 3
# Similar Names:
#  - the revenge of johnny bonasera: episode 1
#  - the revenge of johnny bonasera: episode 2
#
# Base Name: damascus gear operation osaka hd edition
# Similar Names:
#  - damascus gear operation tokyo hd
#
# Base Name: dissidia: final fantasy
# Similar Names:
#  - dissidia: final fantasy universal tuning
#
# Base Name: forager
# Similar Names:
#  - audio forager
#
# Base Name: nanashi no game
# Similar Names:
#  - nanashi no game me
#
# Base Name: twisted edge extreme snowboarding
# Similar Names:
#  - twisted edge snowboarding
#
# Base Name: super bomberman 5
# Similar Names:
#  - bomberman
#  - super bomberman
#  - super bomberman 3
#  - super bomberman 4
#  - super bomberman 2
#  - super bomberman r
#  - bomberman '
#  - bomberman 2
#
# Base Name: shadow run
# Similar Names:
#  - run
#
# Base Name: pro evolution soccer  lite
# Similar Names:
#  - pro evolution soccer 6
#  - pro evolution soccer
#
# Base Name: russian roulette: one life
# Similar Names:
#  - russian roulette
#
# Base Name: soldier of fortune
# Similar Names:
#  - soldier of fortune: payback
#  - soldier of fortune gold
#  - soldier of fortune: gold edition
#
# Base Name: saint seiya: soldiers' soul
# Similar Names:
#  - saint seiya: brave soldiers
#
# Base Name: splinter cell essentials
# Similar Names:
#  - tom clancy's splinter cell: essentials
#
# Base Name: virtua tennis: world tour (jp sales)
# Similar Names:
#  - virtua tennis: world tour
#  - virtua tennis: world tour (us & others sales)
#  - virtua tennis 4: world tour
#
# Base Name: 2 games in 1: disney's brother bear / the lion king 1 1/2
# Similar Names:
#  - disney's brother bear
#  - 2 games in 1: disney princess & the lion king
#
# Base Name: shark tale
# Similar Names:
#  - shark
#
# Base Name: high fidelity
# Similar Names:
#  - fidelity
#
# Base Name: street fighter 30th anniversary collection  - keep the past alive
# Similar Names:
#  - street fighter 30th anniversary collection
#
# Base Name: 8-bit armies
# Similar Names:
#  - e.t. armies
#
# Base Name: the godfather (jp sales)
# Similar Names:
#  - the godfather (us sales)
#  - the godfather
#
# Base Name: need for speed: undercover
# Similar Names:
#  - need for speed undercover
#  - need for speed iii
#  - need for speed
#  - need for speed ()
#  - need for speed ii
#  - the need for speed
#
# Base Name: global agenda
# Similar Names:
#  - agenda
#
# Base Name: men in black: the series
# Similar Names:
#  - men in black the series: crashdown
#  - men in black: the game
#  - men in black: the series 2
#
# Base Name: out of ammo
# Similar Names:
#  - out of ammo: death drive
#
# Base Name: unreal tournament
# Similar Names:
#  - unreal tournament 3 black
#  - unreal tournament iii
#  - unreal tournament: game of the year edition
#  - unreal tournament 3
#  - unreal
#
# Base Name: new international track & field
# Similar Names:
#  - track & field
#  - international track & field
#  - espn international track & field
#  - espn the games: international track & field
#  - international track and field
#
# Base Name: medal of honor: european assault (weekly jp sales)
# Similar Names:
#  - medal of honor european assault
#  - medal of honor: european assault
#  - medal of honor: european assault (all region sales)
#
# Base Name: satellite reign
# Similar Names:
#  - satellite
#
# Base Name: conflict: desert storm
# Similar Names:
#  - conflict: desert storm ii
#  - conflict desert storm™
#
# Base Name: the new tetris
# Similar Names:
#  - tetris
#  - tetris 2
#
# Base Name: assassin's creed® unity
# ...
#  - rising
#
# Base Name: demolition company gold edition
# Similar Names:
#  - demolition company: gold edition
#
# Base Name: sequence
# Similar Names:
#  - [the sequence]
#  - sequence storm
#
# Base Name: shin nippon pro wrestling: toukon retsuden 3
# Similar Names:
#  - shin nippon pro wrestling: toukon retsuden
#  - shin nippon pro wrestling: toukon retsuden 2
#
# Base Name: rogue fable iii
# Similar Names:
#  - fable iii
#
# Base Name: guild quest
# Similar Names:
#  - guild
#  - the guild 2
#  - the guild 3
#
# Base Name: overcooked
# Similar Names:
#  - overcooked! 2
#
# Base Name: high noon vr
# Similar Names:
#  - high noon revolver
#
# Base Name: star trek conquest online
# Similar Names:
#  - star trek online
#  - star trek: conquest
#
# Base Name: forgotten adventure
# Similar Names:
#  - adventure pinball: forgotten island
#
# Base Name: hypership out of control 2
# Similar Names:
#  - hypership out of control
#
# Base Name: socom: u.s. navy seals fireteam bravo
# Similar Names:
#  - socom: u.s. navy seals fireteam bravo 2
#  - socom fireteam bravo
#  - socom ii: u.s. navy seals
#  - socom: u.s. navy seals
#  - socom 4: u.s. navy seals
#  - socom 3: u.s. navy seals
#  - socom: u.s. navy seals fireteam bravo 3
#
# Base Name: the elder scrolls®: legends™
# Similar Names:
#  - the elder scrolls online
#  - the elder scrolls® online
#
# Base Name: sd gundam g generation-f
# Similar Names:
#  - sd gundam g generation portable
#  - sd gundam g generation
#  - sd gundam g generation ds
#  - sd gundam g generation seed
#  - sd gundam g generation wars
#  - sd gundam g generation: overworld
#  - sd gundam g generation: gather beat 2
#  - sd gundam g generation-f.i.f
#  - sd gundam g generation spirits
#  - sd gundam g generation neo
#  - sd gundam g generation world
#  - sd gundam g generation zero
#  - sd gundam g generation: cross drive
#  - sd gundam g generation 3d
#
# Base Name: shadow of the colossus
# Similar Names:
#  - the ico & shadow of the colossus collection
#  - shadow of the colossus : a timeless classic
#
# Base Name: derby stallion
# Similar Names:
#  - derby stallion ii
#  - derby stallion iii
#  - derby stallion p
#  - derby stallion advance
#  - derby stallion ds
#  - derby stallion gold
#
# Base Name: disney's a christmas carol
# Similar Names:
#  - christmas stories: a christmas carol collector's edition
#  - christmas carol
#
# Base Name: car mechanic manager
# Similar Names:
#  - car mechanic simulator
#
# Base Name: dodge this!
# Similar Names:
#  - dodge
#
# Base Name: petz: catz playground
# Similar Names:
#  - petz: catz 2
#
# Base Name: fort
# Similar Names:
#  - fort meow
#  - fort zombie
#  - fort defense
#  - fort awesome
#  - mage fort
#
# Base Name: full bore: the first dig
# Similar Names:
#  - full bore
#
# Base Name: trace memory
# Similar Names:
#  - the trace
#
# Base Name: yu-gi-oh! the eternal duelist soul (jp sales)
# Similar Names:
#  - yu-gi-oh! the eternal duelist soul
#
# Base Name: my baby girl
# Similar Names:
#  - my little baby
#
# Base Name: warioware: twisted!
# Similar Names:
#  - warioware d.i.y.
#
# Base Name: system shock: enhanced edition
# Similar Names:
#  - system shock 2
#
# Base Name: scrabble
# Similar Names:
#  - scrabble complete
#  - multiplayer scrabble
#  - scrabble deluxe
#  - scrabble blast!
#  - scrabble  edition
#
# Base Name: mechcommander gold
# Similar Names:
#  - mechcommander 2
#  - mechcommander
#
# Base Name: bitcoin
# Similar Names:
#  - bitcoin farm
#  - bitcoin vr
#  - bitcoin collector
#  - call of bitcoin
#
# Base Name: everquest
# Similar Names:
#  - lords of everquest
#  - everquest ii
#
# Base Name: one last day
# Similar Names:
#  - the last one
#  - one of the last
#
# Base Name: star wars: the old republic - galactic starfighter
# Similar Names:
#  - star wars: the old republic
#
# Base Name: guilty summer kiss
# Similar Names:
#  - guilty summer kiss 2 - bloody secret
#
# Base Name: disney winnie the pooh
# Similar Names:
#  - disney's winnie the pooh's rumbly tumbly adventure
#
# Base Name: pokemon mystery dungeon: explorers of time/explorers of darkness
# Similar Names:
#  - pokemon mystery dungeon: explorers of darkness
#  - pokemon mystery dungeon: explorers of time
#  - pokemon mystery dungeon: explorers of sky
#
# Base Name: timeshift
# Similar Names:
#  - timeshift™
#
# Base Name: rengoku ii: the stairway to h.e.a.v.e.n.
# Similar Names:
#  - rengoku ii: the stairway to h.e.a.v.e.n. (jp sales)
#  - rengoku ii:  the stairway to h.e.a.v.e.n.
#
# Base Name: dead star
# Similar Names:
#  - dead
#
# Base Name: inazuma eleven
# Similar Names:
#  - inazuma eleven 2: blizzard
#  - inazuma eleven go
#  - inazuma eleven 2
#  - inazuma eleven go strikers
#  - inazuma eleven 3
#  - inazuma eleven go 3: galaxy
#  - inazuma eleven strikers  xtreme
#  - inazuma eleven strikers
#
# Base Name: randall
# Similar Names:
#  - king randall's party
#
# Base Name: sniper: ghost warrior 2
# Similar Names:
#  - sniper: ghost warrior
#  - sniper ghost warrior 3
#
# Base Name: tom and jerry: war of the whiskers
# Similar Names:
#  - tom and jerry in war of the whiskers
#
# Base Name: hotline miami 2: wrong number
# Similar Names:
#  - hotline miami
#
# Base Name: harvest moon: boy & girl
# Similar Names:
#  - harvest moon: boy & girl review
#  - harvest moon
#
# Base Name: serment - contract with a devil
# Similar Names:
#  - contract with the devil
#
# Base Name: mission: impossible - operation surma
# Similar Names:
#  - mission: impossible: operation surma
#
# Base Name: sherlock holmes: crimes & punishments
# Similar Names:
#  - sherlock holmes: crimes and punishments
#
# Base Name: animal crossing: wild world
# Similar Names:
#  - animal crossing
#
# Base Name: hannah montana: the movie
# Similar Names:
#  - hannah montana
#
# Base Name: lines x free
# Similar Names:
#  - lines x
#  - lines
#
# Base Name: islands of wakfu
# Similar Names:
#  - wakfu
#
# Base Name: ultimate puzzle games: sudoku edition
# Similar Names:
#  - ultimate puzzle games
#
# Base Name: rock n' roll racing
# Similar Names:
#  - rock 'n roll
#  - rock 'n' roll defense
#  - rock 'n roll racing
#  - rock 'n' roll adventures
#
# Base Name: gochi-show! -how to learn japanese cooking game-
# Similar Names:
#  - gochi-show! for girls -how to learn japanese cooking game-
#
# Base Name: escape plan
# Similar Names:
#  - the plan
#  - m-plan
#
# Base Name: pro rally
# Similar Names:
#  - v-rally 4
#  - v-rally 3
#
# Base Name: tony la russa baseball 3:  edition
# Similar Names:
#  - tony la russa baseball 4
#
# Base Name: jackass: the game
# Similar Names:
#  - jackass the game
#  - jackass the game ds
#
# Base Name: just cause 4
# Similar Names:
#  - just cause 3
#  - just cause 2
#  - just cause
#  - just cause™ 3
#
# Base Name: planetside 2 updated
# Similar Names:
#  - planetside 2
#  - planetside
#
# Base Name: sinner: sacrifice for redemption  - trials and tribulations
# Similar Names:
#  - sinner: sacrifice for redemption
#
# Base Name: empyrean frontier
# Similar Names:
#  - empyrean
#
# Base Name: aegis
# Similar Names:
#  - aegis defenders
#
# Base Name: the powerpuff girls: bad mojo
# Similar Names:
#  - powerpuff girls: bad mojo jojo
#
# Base Name: deadly days
# Similar Names:
#  - deadly
#
# Base Name: dungeon defenders
# Similar Names:
#  - dungeon defenders ii
#
# Base Name: phantasy star online version 2
# Similar Names:
#  - phantasy star ø
#  - phantasy star online
#  - phantasy star online 2
#
# Base Name: goro 2
# Similar Names:
#  - goro
#
# Base Name: secret files 3
# Similar Names:
#  - f.e.a.r. files
#  - x-files
#  - the x files
#  - secret files: tunguska
#
# Base Name: inazuma eleven strikers
# Similar Names:
#  - inazuma eleven 2
#  - inazuma eleven go strikers
#  - inazuma eleven 3
#  - inazuma eleven strikers  xtreme
#  - inazuma eleven
#
# Base Name: contact draw: bowling
# Similar Names:
#  - contact draw: football
#
# Base Name: forest harvester simulator
# Similar Names:
#  - harvester
#
# Base Name: the cavern
# Similar Names:
#  - cavern of time
#  - cavern escape
#  - dark cavern
#  - cavern kings
#
# Base Name: marble madness / klax
# Similar Names:
#  - marble madness
#
# Base Name: we ski
# Similar Names:
#  - we ski & snowboard
#
# Base Name: sd gundam force: showdown!
# Similar Names:
#  - sd gundam force
#
# Base Name: gakuen hetalia portable
# Similar Names:
#  - gakuen hetalia
#
# Base Name: gunworld
# Similar Names:
#  - super gunworld 2
#
# Base Name: military madness
# Similar Names:
#  - nectaris: military madness
#  - military madness: nectaris
#
# Base Name: guacamelee! gold edition
# Similar Names:
#  - guacamelee! 2
#  - guacamelee!
#
# Base Name: sandbox showdown
# Similar Names:
#  - the sandbox
#
# Base Name: nier
# Similar Names:
#  - nier:automata™
#  - nier: automata
#
# Base Name: pingball ultra
# Similar Names:
#  - pingball vr
#
# Base Name: neo atlas 1469
# Similar Names:
#  - neo atlas
#
# Base Name: space hodsola
# Similar Names:
#  - space hodsola 2
#
# Base Name: super switch
# Similar Names:
#  - 1-2-switch
#
# Base Name: king arthur
# Similar Names:
#  - king arthur ii
#  - king arthur's gold
#
# Base Name: master of illusion
# Similar Names:
#  - illusion
#
# Base Name: stay
# Similar Names:
#  - stay close
#
# Base Name: knight squad
# Similar Names:
#  - x-squad
#  - squad
#
# Base Name: abasralsa
# Similar Names:
#  - dubstep abasralsa
#
# Base Name: just sing! vol. 2
# Similar Names:
#  - just sing!
#
# Base Name: digimon rumble arena 2
# Similar Names:
#  - digimon rumble arena
#
# Base Name: risen 3: titan lords
# Similar Names:
#  - risen 3 - titan lords
#
# Base Name: ultimate ride
# Similar Names:
#  - ride 2
#  - ride
#  - ride 3
#  - $1 ride
#
# Base Name: jikkyou powerful pro yakyuu 6
# Similar Names:
#  - jikkyou powerful pro yakyuu portable 4
#  - jikkyou powerful pro baseball
#  - jikkyou powerful pro yakyuu portable 3
#  - jikkyou powerful pro yakyuu 8
#  - jikkyou powerful pro yakyuu ' kaimakuban
#  - jikkyou powerful pro yakyuu  kaimakuban
#  - jikkyou powerful pro yakyuu ' ketteiban
#  - jikkyou powerful pro yakyuu 7
#  - jikkyou powerful pro yakyuu 3 ' haru
#  - jikkyou powerful pro yakyuu 9 ketteiban
#  - jikkyou powerful pro yakyuu
#  - jikkyou powerful pro yakyuu 3
#  - jikkyou powerful pro yakyuu wii
#  - jikkyou powerful pro yakyuu  ketteiban
#  - jikkyou powerful pro yakyuu 2
#  - jikkyou powerful pro yakyuu wii ketteiban
#  - jikkyou powerful pro yakyuu 5
#  - jikkyou powerful pro yakyuu 9
#  - jikkyou powerful pro yakyuu portable
#  - jikkyou powerful pro yakyuu portable 2
#  - jikkyou powerful pro yakyuu next
#  - jikkyou powerful pro yakyuu '
#  - jikkyou powerful pro yakyuu 4
#  - jikkyou powerful pro yakyuu 8 ketteiban
#  - jikkyou powerful pro yakyuu basic-han
#  - jikkyou powerful pro yakyuu dreamcast edition
#
# Base Name: blazblue: chrono phantasma
# Similar Names:
#  - blazblue: chrono phantasma extend
#
# Base Name: hole in the wall: deluxe edition
# Similar Names:
#  - hole in the wall
#
# Base Name: ultimate i spy
# Similar Names:
#  - spy vs. spy
#  - spy vs spy
#
# Base Name: mass effect 3: omega
# Similar Names:
#  - mass effect
#  - mass effect 2
#  - mass effect 3
#
# Base Name: monster garden
# Similar Names:
#  - the garden
#
# Base Name: links extreme
# Similar Names:
#  - links
#
# Base Name: home wars
# Similar Names:
#  - home
#
# Base Name: cartoon network: punch time explosion
# Similar Names:
#  - cartoon network: punch time explosion xl
#
# Base Name: below
# Similar Names:
#  - forest below
#  - below zero
#  - deep below
#
# Base Name: patrician iv
# Similar Names:
#  - patrician iv: gold edition
#  - patrician ii
#  - patrician iv - steam special edition
#
# Base Name: time recoil
# Similar Names:
#  - recoil
#
# Base Name: sentimental graffiti 2
# Similar Names:
#  - sentimental graffiti
#  - sentimental graffiti: first window
#
# Base Name: air combat
# Similar Names:
#  - air combat arena
#  - air
#
# Base Name: neo angelique special
# Similar Names:
#  - neo angelique
#
# Base Name: star wars: rebel assault ii - the hidden empire
# Similar Names:
#  - star wars™: rebel assault i + ii
#
# Base Name: call of bitcoin
# Similar Names:
#  - bitcoin
#
# Base Name: z: the end
# Similar Names:
#  - the end o,,,o
#  - z-end
#  - end space
#
# Base Name: game center cx: arino no chousenjou 2
# Similar Names:
#  - game center cx: 3-choume no arino
#
# Base Name: vitamin z revolution
# Similar Names:
#  - vitamin y
#  - vitamin x
#  - vitamin r
#  - vitamin z
#
# Base Name: savage offroad
# Similar Names:
#  - savage
#
# Base Name: the sand man
# Similar Names:
#  - vr sand
#
# Base Name: game party 2
# Similar Names:
#  - game party 3
#  - game party
#  - game party: champions
#
# Base Name: rpg maker ii
# Similar Names:
#  - rpg maker
#  - rpg world - action rpg maker
#  - rpg maker 3
#
# Base Name: assassin's creed unity: dead kings
# Similar Names:
#  - assassin's creed® unity
#  - assassin's creed: unity
#  - assassin's creed unity
#
# Base Name: logistical 2
# Similar Names:
#  - logistical: caribbean
#  - logistical: japan
#  - logistical
#
# Base Name: assault android cactus+  - robots rock
# Similar Names:
#  - assault android cactus
#
# Base Name: socom: tactical strike
# Similar Names:
#  - socom: u.s. navy seals tactical strike
#
# Base Name: barbarian brawl
# Similar Names:
#  - barbarian
#
# Base Name: virtual sports
# Similar Names:
#  - virtual-o
#
# Base Name: mega man x legacy collection / ロックマンx アニバーサリー コレクション
# Similar Names:
#  - mega man x legacy collection 2 / ロックマンx アニバーサリー コレクション 2
#
# Base Name: total war: empire – definitive edition
# Similar Names:
#  - total war: medieval ii – definitive edition
#  - empire: total war
#  - total war: napoleon – definitive edition
#
# Base Name: pain: amusement park
# Similar Names:
#  - my amusement park
#
# Base Name: nexus: the jupiter incident
# Similar Names:
#  - nexus - the jupiter incident
#
# Base Name: u-sing  2
# Similar Names:
#  - u-sing
#  - sing party
#  - just sing!
#  - let's sing
#  - we sing
#
# Base Name: worms pinball
# Similar Names:
#  - worms
#  - worms w.m.d.
#  - worms w.m.d
#  - worms 2
#
# Base Name: intelligence: dogs
# Similar Names:
#  - intelligence
#
# Base Name: super fire prowrestling
# Similar Names:
#  - fire prowrestling g
#  - super fire prowrestling special
#  - fire prowrestling g (import)
#  - fire prowrestling
#  - super fire prowrestling x
#  - fire prowrestling z
#
# Base Name: tony hawk's pro skater 1 + 2  – i'm a superman
# Similar Names:
#  - tony hawk's pro skater 2
#  - tony hawk's pro skater
#  - tony hawk's pro skater 3d
#  - tony hawk's pro skater 2x
#  - tony hawk's pro skater 3
#  - tony hawk's pro skater hd
#  - tony hawk's pro skater 4
#  - tony hawk's pro skater 5
#
# Base Name: sonic the hedgehog 4 - episode ii
# Similar Names:
#  - sonic the hedgehog 4: episode ii
#  - sonic the hedgehog arcade
#  - sonic the hedgehog 4: episode 1
#  - sonic the hedgehog
#  - sonic the hedgehog 3
#  - sonic the hedgehog 2
#
# Base Name: chameleon man
# Similar Names:
#  - chameleon
#
# Base Name: labours of hercules
# Similar Names:
#  - labours of hercules iii: girl power
#
# Base Name: hanayaka kana, ware ga ichizoku
# Similar Names:
#  - hanayaka kana, ware ga ichizoku: tasogare polarstar
#  - hanayaka kana, ware ga ichizoku twin pack
#
# Base Name: eternal step
# Similar Names:
#  - jump, step, step
#
# Base Name: torn tales: rebound edition
# Similar Names:
#  - torn tales
#
# Base Name: hitman: absolution
# Similar Names:
#  - hitman: absolution™
#
# Base Name: hack, slash, loot
# Similar Names:
#  - hack 'n' slash
#
# Base Name: super robot taisen: scramble commander the 2nd
# Similar Names:
#  - super robot taisen: scramble commander
#
# Base Name: 187: ride or die
# Similar Names:
#  - 187 ride or die
#
# Base Name: 3rd super robot wars z: tengoku-hen
# Similar Names:
#  - 3rd super robot wars z jigoku hen
#
# Base Name: emergency 2
# Similar Names:
#  - emergency room 2
#  - emergency 3
#  - emergency
#  - emergency mayhem
#  - emergency 4 deluxe
#  - emergency heroes
#
# Base Name: shadow uprising
# Similar Names:
#  - uprising x
#  - uprising
#
# Base Name: radical spectrum: volume 1
# Similar Names:
#  - radical spectrum: volume 2
#
# Base Name: death mark
# Similar Names:
#  - the mark
#
# Base Name: ys: the ark of napishtim
# Similar Names:
#  - ys vi: the ark of napishtim
#
# Base Name: beyond the wall
# Similar Names:
#  - wall-e
#  - the wall
#
# Base Name: wing island
# Similar Names:
#  - 5. wing
#
# Base Name: earth 2150 trilogy
# Similar Names:
#  - earth 2150
#
# Base Name: universe sandbox ²
# Similar Names:
#  - the sandbox
#
# Base Name: the sims™ 3
# Similar Names:
#  - the sims deluxe
#  - the sims 2
#  - the sims 4
#  - the sims 3: world adventures
#  - the sims 3 world adventures
#  - the sims 2 mobile
#  - the sims: unleashed
#  - the sims medieval
#  - the sims: medieval
#  - the sims
#  - the sims 3
#
# Base Name: battle islands
# Similar Names:
#  - worms: battle islands
#
# Base Name: bubble burst
# Similar Names:
#  - burst
#
# Base Name: yu-gi-oh! world championship
# Similar Names:
#  - yu-gi-oh! 7 trials to glory: world championship tournament
#  - yu-gi-oh! world championship tournament
#  - yu-gi-oh! ultimate masters: world championship tournament
#  - yu-gi-oh! 5d's world championship : over the nexus
#  - yu-gi-oh! online

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rapidfuzz import fuzz
import re
from datetime import datetime

# Load the datasets
games_updated_df = pd.read_csv('Downloads/Games_Updated.csv')
steam_df = pd.read_csv('Downloads/steam.csv')
vgsales_df = pd.read_csv('Downloads/vgsales-2.csv')

# Extract and standardize release years
def extract_year(date_str):
    try:
        return datetime.strptime(date_str, "%Y").year
    except ValueError:
        try:
            return datetime.strptime(date_str, "%Y-%m-%d").year
        except ValueError:
            try:
                return datetime.strptime(date_str, "%m/%d/%Y").year
            except ValueError:
                return None

# Add standardized year columns based on available date columns
games_updated_df['Year'] = None
if 'Release_Date' in steam_df.columns:
    steam_df['Year'] = steam_df['Release_Date'].apply(lambda x: extract_year(str(x)))
if 'Release_Year' in vgsales_df.columns:
    vgsales_df['Year'] = vgsales_df['Release_Year'].apply(lambda x: int(x) if pd.notnull(x) else None)

# Function to remove years from names
def remove_years(name):
    return re.sub(r'\b(19|20)?\d{2}\b', '', name).strip()

# Collect all names, years, and source identifiers into a unified list
games_updated_names = [(remove_years(name), year, "Games_Updated") for name, year in zip(games_updated_df['Game_Name'].str.lower(), games_updated_df['Year'])]
steam_names = [(remove_years(name), year, "Steam") for name, year in zip(steam_df['Game_Name'].str.lower(), steam_df['Year'])]
vgsales_names = [(remove_years(name), year, "VG_Sales") for name, year in zip(vgsales_df['Game_Name'].str.lower(), vgsales_df['Year'])]

# Combine all names and years with sources
all_game_names = list(set(games_updated_names + steam_names + vgsales_names))

# Vectorize the game names only (for matching by name)
vectorizer = TfidfVectorizer().fit_transform([name for name, year, source in all_game_names])
cosine_similarities = cosine_similarity(vectorizer)

# Set high threshold for cosine similarity and token-based similarity
COSINE_THRESHOLD = 0.8
TOKEN_THRESHOLD = 90

# Identify similar names based on cosine similarity, token similarity, same year, and different source
similar_names = {}
for idx, (name, year, source) in enumerate(all_game_names):
    similar_indices = cosine_similarities[idx] >= COSINE_THRESHOLD
    for i in range(len(all_game_names)):
        # Check if cosine similarity is above threshold, token similarity matches, years match, and sources differ
        if (
            similar_indices[i] and i != idx and all_game_names[i][1] == year 
            and all_game_names[i][2] != source
        ):
            token_similarity = fuzz.token_sort_ratio(name, all_game_names[i][0])
            word_count_difference = abs(len(name.split()) - len(all_game_names[i][0].split()))
            
            if token_similarity >= TOKEN_THRESHOLD and word_count_difference <= 1:
                if name not in similar_names:
                    similar_names[name] = []
                similar_names[name].append((all_game_names[i][0], all_game_names[i][1], all_game_names[i][2], cosine_similarities[idx, i]))

# Display results sorted by similarity score
for base_name, matches in list(similar_names.items()):  # Show first 10 matches for readability
    print(f"Base Name: {base_name}")
    print("Similar Names:")
    for match_name, match_year, match_source, similarity in sorted(matches, key=lambda x: -x[3]):  # Sort by descending similarity
        print(f" - {match_name} (Year: {match_year}, Source: {match_source}, Similarity: {similarity:.2f})")
    print()
# Out:
# Base Name: batman: arkham origins
# Similar Names:
#  - batman™: arkham origins (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: the darkness ii
# Similar Names:
#  - the darkness ii (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - the darkness ii (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: bound by flame
# Similar Names:
#  - bound by flame (Year: 2014, Source: Steam, Similarity: 1.00)
#  - bound by flame (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: the evil within
# Similar Names:
#  - the evil within (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - the evil within (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: xcom 2
# Similar Names:
#  - xcom® 2 (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: dead space™ 2
# Similar Names:
#  - dead space 2 (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: serious sam 3: bfe
# Similar Names:
#  - serious sam 3: bfe (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - serious sam 3: bfe (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: dc universe™ online
# Similar Names:
#  - dc universe online (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: child of light
# Similar Names:
#  - child of light (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - child of light (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: project cars
# Similar Names:
#  - project cars (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - project cars (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: mx vs. atv supercross encore
# Similar Names:
#  - mx vs. atv supercross encore (Year: 2015, Source: Steam, Similarity: 1.00)
#  - mx vs. atv supercross encore (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: sniper: ghost warrior
# Similar Names:
#  - sniper: ghost warrior (Year: 2010, Source: Steam, Similarity: 1.00)
#  - sniper: ghost warrior (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: terraria
# Similar Names:
#  - terraria (Year: 2011, Source: Steam, Similarity: 1.00)
#  - terraria (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: tropico 4
# Similar Names:
#  - tropico 4 (Year: 2011, Source: Steam, Similarity: 1.00)
#  - tropico 4 (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty: modern warfare 2
# Similar Names:
#  - call of duty®: modern warfare® 2 (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: farming simulator
# Similar Names:
#  - farming simulator (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - farming simulator (Year: 2014, Source: Steam, Similarity: 1.00)
#  - farming simulator (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - farming simulator (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: risen 3 - titan lords
# Similar Names:
#  - risen 3: titan lords (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: pac-man and the ghostly adventures 2
# Similar Names:
#  - pac-man™ and the ghostly adventures (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: fallout 3
# Similar Names:
#  - fallout 3 (Year: 2008, Source: Steam, Similarity: 1.00)
#  - fallout 3 (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: puzzle chronicles
# Similar Names:
#  - puzzle chronicles (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - puzzle chronicles (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: shantae and the pirate's curse
# Similar Names:
#  - shantae and the pirate's curse (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - shantae and the pirate's curse (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: the sims™ 3
# Similar Names:
#  - the sims 3 (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: pac-man™ and the ghostly adventures
# Similar Names:
#  - pac-man and the ghostly adventures 2 (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: trapped dead
# Similar Names:
#  - trapped dead (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - trapped dead (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: half-life 2
# Similar Names:
#  - half-life 2 (Year: 2004.0, Source: VG_Sales, Similarity: 1.00)
#  - half-life 2 (Year: 2004, Source: Steam, Similarity: 1.00)
#
# Base Name: zombie army trilogy
# Similar Names:
#  - zombie army trilogy (Year: 2015, Source: Steam, Similarity: 1.00)
#  - zombie army trilogy (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: mass effect 2
# Similar Names:
#  - mass effect 2 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - mass effect 2 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: grid 2
# Similar Names:
#  - grid 2 (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#  - grid 2 (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: brink
# Similar Names:
#  - brink (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - brink (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: payday 2
# Similar Names:
#  - payday 2 (Year: 2013, Source: Steam, Similarity: 1.00)
#  - payday 2 (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty: black ops ii
# Similar Names:
#  - call of duty®: black ops ii (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: mount & blade
# Similar Names:
#  - mount & blade (Year: 2008, Source: Steam, Similarity: 1.00)
#  - mount & blade (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: men of war: assault squad
# Similar Names:
#  - men of war: assault squad (Year: 2011, Source: Steam, Similarity: 1.00)
#  - men of war: assault squad (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: s.t.a.l.k.e.r.: shadow of chernobyl
# Similar Names:
#  - s.t.a.l.k.e.r.: shadow of chernobyl (Year: 2007, Source: Steam, Similarity: 1.00)
#  - s.t.a.l.k.e.r.: shadow of chernobyl (Year: 2007.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: street fighter® iv
# Similar Names:
#  - street fighter iv (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: hearts of iron iii
# Similar Names:
#  - hearts of iron iii (Year: 2009, Source: Steam, Similarity: 1.00)
#  - hearts of iron iii (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: command & conquer 4: tiberian twilight
# Similar Names:
#  - command & conquer 4: tiberian twilight (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - command & conquer 4: tiberian twilight (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: oil rush
# Similar Names:
#  - oil rush (Year: 2012, Source: Steam, Similarity: 1.00)
#  - oil rush (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: grand theft auto v
# Similar Names:
#  - grand theft auto v (Year: 2015, Source: Steam, Similarity: 1.00)
#  - grand theft auto v (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: saints row iv
# Similar Names:
#  - saints row iv (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#  - saints row iv (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: tales of zestiria
# Similar Names:
#  - tales of zestiria (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - tales of zestiria (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: ducktales: remastered
# Similar Names:
#  - ducktales: remastered (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#  - ducktales: remastered (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: tropico reloaded
# Similar Names:
#  - tropico reloaded (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - tropico reloaded (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: burnout paradise: the ultimate box
# Similar Names:
#  - burnout paradise: the ultimate box (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - burnout paradise: the ultimate box (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: mafia
# Similar Names:
#  - mafia (Year: 2002.0, Source: VG_Sales, Similarity: 1.00)
#  - mafia (Year: 2002, Source: Steam, Similarity: 1.00)
#
# Base Name: motogp
# Similar Names:
#  - motogp™ (Year: 2014, Source: Steam, Similarity: 1.00)
#  - motogp™ (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: the next big thing
# Similar Names:
#  - the next big thing (Year: 2011, Source: Steam, Similarity: 1.00)
#  - the next big thing (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: contrast
# Similar Names:
#  - contrast (Year: 2013, Source: Steam, Similarity: 1.00)
#  - contrast (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: the lego movie videogame
# Similar Names:
#  - the lego® movie - videogame (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: supreme commander 2
# Similar Names:
#  - supreme commander 2 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - supreme commander 2 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: handball
# Similar Names:
#  - handball (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - handball (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: men of war
# Similar Names:
#  - men of war™ (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: sid meier's civilization®: beyond earth™
# Similar Names:
#  - sid meier's civilization: beyond earth (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: valentino rossi the game
# Similar Names:
#  - valentino rossi: the game (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: nba 2k17
# Similar Names:
#  - nba 2k17 (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - nba 2k17 (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: air conflicts: secret wars
# Similar Names:
#  - air conflicts: secret wars (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - air conflicts: secret wars (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: anno ™
# Similar Names:
#  - anno (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: saints row 2
# Similar Names:
#  - saints row 2 (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - saints row 2 (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: peggle™ nights
# Similar Names:
#  - peggle nights (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: prince of persia: the forgotten sands™
# Similar Names:
#  - prince of persia: the forgotten sands (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: cities in motion
# Similar Names:
#  - cities in motion (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - cities in motion (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: sherlock holmes: the mystery of the mummy
# Similar Names:
#  - sherlock holmes: the mystery of the mummy (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - sherlock holmes: the mystery of the mummy (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's ghost recon: future soldier™
# Similar Names:
#  - tom clancy's ghost recon: future soldier (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: assassin's creed syndicate
# Similar Names:
#  - assassin's creed® syndicate (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: f1
# Similar Names:
#  - f1 (Year: 2014, Source: Steam, Similarity: 1.00)
#  - f1 (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - f1 ™ (Year: 2012, Source: Steam, Similarity: 1.00)
#  - f1 (Year: 2011, Source: Steam, Similarity: 1.00)
#  - f1 (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - f1 (Year: 2015, Source: Steam, Similarity: 1.00)
#  - f1 (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dmc: devil may cry
# Similar Names:
#  - dmc: devil may cry (Year: 2013, Source: Steam, Similarity: 1.00)
#  - dmc: devil may cry (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: velvet assassin
# Similar Names:
#  - velvet assassin (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - velvet assassin (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: battlestations: midway
# Similar Names:
#  - battlestations: midway (Year: 2007.0, Source: VG_Sales, Similarity: 1.00)
#  - battlestations: midway (Year: 2007, Source: Steam, Similarity: 1.00)
#
# Base Name: the golf club
# Similar Names:
#  - the golf club (Year: 2014, Source: Steam, Similarity: 1.00)
#  - the golf club (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: the witcher 3: wild hunt
# Similar Names:
#  - the witcher® 3: wild hunt (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: x rebirth
# Similar Names:
#  - x rebirth (Year: 2013, Source: Steam, Similarity: 1.00)
#  - x rebirth (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: operation flashpoint: dragon rising
# Similar Names:
#  - operation flashpoint: dragon rising (Year: 2009, Source: Steam, Similarity: 1.00)
#  - operation flashpoint: dragon rising (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: saints row: gat out of hell
# Similar Names:
#  - saints row: gat out of hell (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - saints row: gat out of hell (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: risen 2: dark waters
# Similar Names:
#  - risen 2: dark waters (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - risen 2: dark waters (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: sniper: ghost warrior 2
# Similar Names:
#  - sniper: ghost warrior 2 (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#  - sniper: ghost warrior 2 (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: medal of honor™
# Similar Names:
#  - medal of honor (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: tom clancy's splinter cell: blacklist
# Similar Names:
#  - tom clancy’s splinter cell blacklist (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: rage
# Similar Names:
#  - rage (Year: 2011, Source: Steam, Similarity: 1.00)
#  - rage (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: quantum break
# Similar Names:
#  - quantum break (Year: 2016, Source: Steam, Similarity: 1.00)
#  - quantum break (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: kingdoms of amalur: reckoning
# Similar Names:
#  - kingdoms of amalur: reckoning™ (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: don bradman cricket
# Similar Names:
#  - don bradman cricket (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - don bradman cricket (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: call of juarez™
# Similar Names:
#  - call of juarez (Year: 2007.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: thief ()
# Similar Names:
#  - thief (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: castlevania: lords of shadow 2
# Similar Names:
#  - castlevania: lords of shadow 2 (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - castlevania: lords of shadow 2 (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: train simulator
# Similar Names:
#  - train simulator (Year: 2015, Source: Steam, Similarity: 1.00)
#  - train simulator (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: company of heroes
# Similar Names:
#  - company of heroes (Year: 2006, Source: Steam, Similarity: 1.00)
#  - company of heroes (Year: 2006.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: ridge racer™ unbounded
# Similar Names:
#  - ridge racer unbounded (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: prince of persia®
# Similar Names:
#  - prince of persia () (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - prince of persia (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: apb reloaded
# Similar Names:
#  - apb reloaded (Year: 2011, Source: Steam, Similarity: 1.00)
#  - apb reloaded (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: tomb raider: anniversary
# Similar Names:
#  - tomb raider: anniversary (Year: 2007.0, Source: VG_Sales, Similarity: 1.00)
#  - tomb raider: anniversary (Year: 2007, Source: Steam, Similarity: 1.00)
#
# Base Name: nancy drew: alibi in ashes
# Similar Names:
#  - nancy drew®: alibi in ashes (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: dark void
# Similar Names:
#  - dark void™ (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: hunted: the demon’s forge™
# Similar Names:
#  - hunted: the demon's forge (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: rugby world cup
# Similar Names:
#  - rugby world cup (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - rugby world cup (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: magicka
# Similar Names:
#  - magicka (Year: 2011, Source: Steam, Similarity: 1.00)
#  - magicka (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: cities: skylines
# Similar Names:
#  - cities: skylines (Year: 2015, Source: Steam, Similarity: 1.00)
#  - cities: skylines (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: men of war: vietnam
# Similar Names:
#  - men of war: vietnam (Year: 2011, Source: Steam, Similarity: 1.00)
#  - men of war: vietnam (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: saints row: the third
# Similar Names:
#  - saints row: the third (Year: 2011, Source: Steam, Similarity: 1.00)
#  - saints row: the third (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: hunted: the demon's forge
# Similar Names:
#  - hunted: the demon’s forge™ (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: hearts of iron iv
# Similar Names:
#  - hearts of iron iv (Year: 2016, Source: Steam, Similarity: 1.00)
#  - hearts of iron iv (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: the technomancer
# Similar Names:
#  - the technomancer (Year: 2016, Source: Steam, Similarity: 1.00)
#  - the technomancer (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: duke nukem forever
# Similar Names:
#  - duke nukem forever (Year: 2011, Source: Steam, Similarity: 1.00)
#  - duke nukem forever (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: borderlands 2
# Similar Names:
#  - borderlands 2 (Year: 2012, Source: Steam, Similarity: 1.00)
#  - borderlands 2 (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: rise of the tomb raider™
# Similar Names:
#  - rise of the tomb raider (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: the inner world
# Similar Names:
#  - the inner world (Year: 2013, Source: Steam, Similarity: 1.00)
#  - the inner world (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: x-blades
# Similar Names:
#  - x-blades (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - x-blades (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: assassin’s creed® chronicles: china
# Similar Names:
#  - assassin's creed chronicles: china (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: rollercoaster tycoon world
# Similar Names:
#  - rollercoaster tycoon world™ (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: brothers in arms: hell's highway™
# Similar Names:
#  - brothers in arms: hell's highway (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: xcom: enemy unknown
# Similar Names:
#  - xcom: enemy unknown (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - xcom: enemy unknown (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: legend of kay anniversary
# Similar Names:
#  - legend of kay anniversary (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - legend of kay anniversary (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: mad max
# Similar Names:
#  - mad max () (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: the bureau: xcom declassified
# Similar Names:
#  - the bureau: xcom declassified (Year: 2013, Source: Steam, Similarity: 1.00)
#  - the bureau: xcom declassified (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dc universe online
# Similar Names:
#  - dc universe™ online (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: blood bowl - legendary edition
# Similar Names:
#  - blood bowl: legendary edition (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: botanicula
# Similar Names:
#  - botanicula (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - botanicula (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: dragon ball: xenoverse
# Similar Names:
#  - dragon ball xenoverse (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: kane & lynch 2: dog days
# Similar Names:
#  - kane & lynch 2: dog days (Year: 2010, Source: Steam, Similarity: 1.00)
#  - kane & lynch 2: dog days (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: blades of time
# Similar Names:
#  - blades of time (Year: 2012, Source: Steam, Similarity: 1.00)
#  - blades of time (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: sherlock holmes: crimes and punishments
# Similar Names:
#  - sherlock holmes: crimes & punishments (Year: 2014.0, Source: VG_Sales, Similarity: 0.96)
#
# Base Name: conflict: denied ops
# Similar Names:
#  - conflict: denied ops (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - conflict: denied ops (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: bejeweled® 3
# Similar Names:
#  - bejeweled 3 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: mini ninjas
# Similar Names:
#  - mini ninjas (Year: 2009, Source: Steam, Similarity: 1.00)
#  - mini ninjas (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: need for speed: hot pursuit
# Similar Names:
#  - need for speed: hot pursuit (Year: 2010, Source: Steam, Similarity: 1.00)
#  - need for speed: hot pursuit (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: mighty no. 9
# Similar Names:
#  - mighty no. 9 (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - mighty no. 9 (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: dungeon defenders
# Similar Names:
#  - dungeon defenders (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - dungeon defenders (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: ninja blade
# Similar Names:
#  - ninja blade (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - ninja blade (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: the crew
# Similar Names:
#  - the crew™ (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: f1 race stars™
# Similar Names:
#  - f1 race stars (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: yaiba: ninja gaiden z
# Similar Names:
#  - yaiba: ninja gaiden z (Year: 2014, Source: Steam, Similarity: 1.00)
#  - yaiba: ninja gaiden z (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lara croft and the temple of osiris™
# Similar Names:
#  - lara croft and the temple of osiris (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of juarez®: bound in blood
# Similar Names:
#  - call of juarez: bound in blood (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: goodbye deponia
# Similar Names:
#  - goodbye deponia (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#  - goodbye deponia (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: prince of persia ()
# Similar Names:
#  - prince of persia® (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: dead rising®
# Similar Names:
#  - dead rising (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dragon ball xenoverse
# Similar Names:
#  - dragon ball: xenoverse (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: legendary
# Similar Names:
#  - legendary (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - legendary (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: scribblenauts unmasked: a dc comics adventure
# Similar Names:
#  - scribblenauts unmasked: a dc comics adventure (Year: 2013, Source: Steam, Similarity: 1.00)
#  - scribblenauts unmasked: a dc comics adventure (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lego® marvel's avengers
# Similar Names:
#  - lego marvel's avengers (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: bioshock infinite
# Similar Names:
#  - bioshock infinite (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#  - bioshock infinite (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: mirror's edge
# Similar Names:
#  - mirror's edge™ (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: lego® harry potter: years 1-4
# Similar Names:
#  - lego harry potter: years 1-4 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dead space 2
# Similar Names:
#  - dead space™ 2 (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: nail'd
# Similar Names:
#  - nail'd (Year: 2010, Source: Steam, Similarity: 1.00)
#  - nail'd (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: murdered: soul suspect
# Similar Names:
#  - murdered: soul suspect (Year: 2014, Source: Steam, Similarity: 1.00)
#  - murdered: soul suspect (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: world of zoo
# Similar Names:
#  - world of zoo (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - world of zoo (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: motogp™
# Similar Names:
#  - motogp (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - motogp (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: tom clancy’s the division™
# Similar Names:
#  - tom clancy's the division (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: take on helicopters
# Similar Names:
#  - take on helicopters (Year: 2011, Source: Steam, Similarity: 1.00)
#  - take on helicopters (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: worms reloaded
# Similar Names:
#  - worms reloaded (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - worms reloaded (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: batman: arkham knight
# Similar Names:
#  - batman™: arkham knight (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: ceville
# Similar Names:
#  - ceville (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - ceville (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: dying light
# Similar Names:
#  - dying light (Year: 2015, Source: Steam, Similarity: 1.00)
#  - dying light (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: game of thrones
# Similar Names:
#  - game of thrones (Year: 2012, Source: Steam, Similarity: 1.00)
#  - game of thrones (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: sonic & sega all-stars racing
# Similar Names:
#  - sonic & sega all-stars racing (Year: 2010, Source: Steam, Similarity: 1.00)
#  - sonic & sega all-stars racing (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: enemy front
# Similar Names:
#  - enemy front (Year: 2014, Source: Steam, Similarity: 1.00)
#  - enemy front (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: commander: conquest of the americas
# Similar Names:
#  - commander: conquest of the americas (Year: 2010, Source: Steam, Similarity: 1.00)
#  - commander: conquest of the americas (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: naruto shippuden: ultimate ninja storm revolution
# Similar Names:
#  - naruto shippuden: ultimate ninja storm revolution (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - naruto shippuden: ultimate ninja storm revolution (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's rainbow six® siege
# Similar Names:
#  - tom clancy's rainbow six: siege (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: sengoku
# Similar Names:
#  - sengoku (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - sengoku (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: assassin's creed: rogue
# Similar Names:
#  - assassin’s creed® rogue (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: lost planet® 3
# Similar Names:
#  - lost planet 3 (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: battlefield: bad company 2
# Similar Names:
#  - battlefield: bad company™ 2 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: off-road drive
# Similar Names:
#  - off-road drive (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - off-road drive (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: far cry® 4
# Similar Names:
#  - far cry 4 (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: goosebumps: the game
# Similar Names:
#  - goosebumps: the game (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - goosebumps: the game (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's endwar™
# Similar Names:
#  - tom clancy's endwar (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: star wars: the force unleashed ii
# Similar Names:
#  - star wars™: the force unleashed™ ii (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: fallout 4
# Similar Names:
#  - fallout 4 (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - fallout 4 (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: mass effect
# Similar Names:
#  - mass effect (Year: 2008, Source: Steam, Similarity: 1.00)
#  - mass effect (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: rugby challenge 3
# Similar Names:
#  - rugby challenge 3 (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - rugby challenge 3 (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: king's bounty: armored princess
# Similar Names:
#  - king's bounty: armored princess (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - king's bounty: armored princess (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: overlord ii
# Similar Names:
#  - overlord ii (Year: 2009, Source: Steam, Similarity: 1.00)
#  - overlord ii (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: assassin's creed® revelations
# Similar Names:
#  - assassin's creed: revelations (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: alpha protocol
# Similar Names:
#  - alpha protocol™ (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: lego batman 2: dc super heroes
# Similar Names:
#  - lego® batman™ 2: dc super heroes (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: spore™ galactic adventures
# Similar Names:
#  - spore galactic adventures (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: portal 2
# Similar Names:
#  - portal 2 (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - portal 2 (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: puzzle quest: galactrix
# Similar Names:
#  - puzzle quest: galactrix (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - puzzle quest: galactrix (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: singularity™
# Similar Names:
#  - singularity (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: alien: isolation
# Similar Names:
#  - alien: isolation (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - alien: isolation (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: one piece: pirate warriors 3
# Similar Names:
#  - one piece pirate warriors 3 (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: far cry 3
# Similar Names:
#  - far cry 3 (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - far cry 3 (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: secret files 2: puritas cordis
# Similar Names:
#  - secret files 2: puritas cordis (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - secret files 2: puritas cordis (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: tomb raider ()
# Similar Names:
#  - tomb raider (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: mortal kombat x
# Similar Names:
#  - mortal kombat x (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - mortal kombat x (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: agatha christie's the abc murders
# Similar Names:
#  - agatha christie - the abc murders (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: assassin's creed: revelations
# Similar Names:
#  - assassin's creed® revelations (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: street fighter v
# Similar Names:
#  - street fighter v (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - street fighter v (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: call of duty®: black ops
# Similar Names:
#  - call of duty: black ops (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: alan wake
# Similar Names:
#  - alan wake (Year: 2012, Source: Steam, Similarity: 1.00)
#  - alan wake (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: x3: terran conflict
# Similar Names:
#  - x3: terran conflict (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - x3: terran conflict (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: crazy machines
# Similar Names:
#  - crazy machines 2 (Year: 2008, Source: Steam, Similarity: 1.00)
#  - crazy machines (Year: 2008, Source: Steam, Similarity: 1.00)
#  - crazy machines (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dragon age origins: awakening
# Similar Names:
#  - dragon age™: origins awakening (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: dungeons
# Similar Names:
#  - dungeons (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - dungeons (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: homefront®: the revolution
# Similar Names:
#  - homefront: the revolution (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dead rising 2: off the record
# Similar Names:
#  - dead rising 2: off the record (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - dead rising 2: off the record (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: prince of persia: the forgotten sands
# Similar Names:
#  - prince of persia: the forgotten sands™ (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: jack keane
# Similar Names:
#  - jack keane (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - jack keane (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: call of juarez: bound in blood
# Similar Names:
#  - call of juarez®: bound in blood (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: assassin's creed iv: black flag
# Similar Names:
#  - assassin’s creed® iv black flag™ (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: l.a. noire
# Similar Names:
#  - l.a. noire (Year: 2011, Source: Steam, Similarity: 1.00)
#  - l.a. noire (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: torchlight
# Similar Names:
#  - torchlight (Year: 2009, Source: Steam, Similarity: 1.00)
#  - torchlight (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: spec ops: the line
# Similar Names:
#  - spec ops: the line (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - spec ops: the line (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: escape dead island
# Similar Names:
#  - escape dead island (Year: 2014, Source: Steam, Similarity: 1.00)
#  - escape dead island (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: world of goo
# Similar Names:
#  - world of goo (Year: 2008, Source: Steam, Similarity: 1.00)
#  - world of goo (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: crysis warhead®
# Similar Names:
#  - crysis: warhead (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: xcom® 2
# Similar Names:
#  - xcom 2 (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: puzzle kingdoms
# Similar Names:
#  - puzzle kingdoms (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - puzzle kingdoms (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: dungeon siege ii
# Similar Names:
#  - dungeon siege ii (Year: 2005, Source: Steam, Similarity: 1.00)
#  - dungeon siege ii (Year: 2005.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: just cause 2
# Similar Names:
#  - just cause 2 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - just cause 2 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: borderlands: the pre-sequel
# Similar Names:
#  - borderlands: the pre-sequel (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - borderlands: the pre-sequel (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: rogue warrior
# Similar Names:
#  - rogue warrior (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - rogue warrior (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: tropico 3
# Similar Names:
#  - tropico 3 (Year: 2009, Source: Steam, Similarity: 1.00)
#  - tropico 3 (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: street fighter x tekken
# Similar Names:
#  - street fighter x tekken (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - street fighter x tekken (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: dragon age: origins
# Similar Names:
#  - dragon age: origins (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - dragon age: origins (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: nancy drew®: alibi in ashes
# Similar Names:
#  - nancy drew: alibi in ashes (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: the elder scrolls v: skyrim
# Similar Names:
#  - the elder scrolls v: skyrim (Year: 2011, Source: Steam, Similarity: 1.00)
#  - the elder scrolls v: skyrim (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: company of heroes: tales of valor
# Similar Names:
#  - company of heroes: tales of valor (Year: 2009, Source: Steam, Similarity: 1.00)
#  - company of heroes: tales of valor (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: company of heroes: opposing fronts
# Similar Names:
#  - company of heroes: opposing fronts (Year: 2007.0, Source: VG_Sales, Similarity: 1.00)
#  - company of heroes: opposing fronts (Year: 2007, Source: Steam, Similarity: 1.00)
#
# Base Name: summer athletics
# Similar Names:
#  - summer athletics (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - summer athletics (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: one piece: burning blood
# Similar Names:
#  - one piece burning blood (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: warhammer ,000: dawn of war ii
# Similar Names:
#  - warhammer ,000: dawn of war ii (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - warhammer ,000: dawn of war ii (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: total war: warhammer
# Similar Names:
#  - total war: warhammer (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - total war: warhammer (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: demolition company: gold edition
# Similar Names:
#  - demolition company gold edition (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's endwar
# Similar Names:
#  - tom clancy's endwar™ (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: elven legacy
# Similar Names:
#  - elven legacy (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - elven legacy (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: lost planet® 2
# Similar Names:
#  - lost planet 2 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: grid autosport
# Similar Names:
#  - grid autosport (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - grid autosport (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: bus simulator
# Similar Names:
#  - bus simulator (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - bus simulator (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: one piece burning blood
# Similar Names:
#  - one piece: burning blood (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: grand theft auto: san andreas
# Similar Names:
#  - grand theft auto: san andreas (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - grand theft auto: san andreas (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: samurai warriors 4-ii
# Similar Names:
#  - samurai warriors 4-ii (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - samurai warriors 4-ii (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: fallout: new vegas
# Similar Names:
#  - fallout: new vegas (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - fallout: new vegas (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: lego® batman™ 2: dc super heroes
# Similar Names:
#  - lego batman 2: dc super heroes (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: rugby league live 3
# Similar Names:
#  - rugby league live 3 (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - rugby league live 3 (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: total war: attila
# Similar Names:
#  - total war: attila (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - total war: attila (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: lego batman: the videogame
# Similar Names:
#  - lego® batman™: the videogame (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: spore
# Similar Names:
#  - spore™ (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: dragon age™: origins awakening
# Similar Names:
#  - dragon age origins: awakening (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: bionic commando
# Similar Names:
#  - bionic commando (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - bionic commando (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: lego harry potter: years 5-7
# Similar Names:
#  - lego® harry potter: years 5-7 (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: rise of the tomb raider
# Similar Names:
#  - rise of the tomb raider™ (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: mount & blade: warband
# Similar Names:
#  - mount & blade: warband (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - mount & blade: warband (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: tomb raider: underworld
# Similar Names:
#  - tomb raider: underworld (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - tomb raider: underworld (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: war for the overworld
# Similar Names:
#  - war for the overworld (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - war for the overworld (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: r.b.i. baseball
# Similar Names:
#  - r.b.i. baseball (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - r.b.i. baseball (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: front mission evolved
# Similar Names:
#  - front mission evolved (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - front mission evolved (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: guilty gear xrd -revelator-
# Similar Names:
#  - guilty gear xrd -revelator- (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - guilty gear xrd -revelator- (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: lego harry potter: years 1-4
# Similar Names:
#  - lego® harry potter: years 1-4 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: alpha protocol™
# Similar Names:
#  - alpha protocol (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: mirror's edge™
# Similar Names:
#  - mirror's edge (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lords of the fallen™
# Similar Names:
#  - lords of the fallen (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dead rising® 2
# Similar Names:
#  - dead rising 2 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: homefront
# Similar Names:
#  - homefront (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - homefront (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: crazy machines 2
# Similar Names:
#  - crazy machines (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: no man's sky
# Similar Names:
#  - no man's sky (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - no man's sky (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's ghost recon: future soldier
# Similar Names:
#  - tom clancy's ghost recon: future soldier™ (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: song of the deep
# Similar Names:
#  - song of the deep (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - song of the deep (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: naruto shippuden: ultimate ninja storm 4
# Similar Names:
#  - naruto shippuden: ultimate ninja storm 4 (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - naruto shippuden: ultimate ninja storm 4 (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: damnation
# Similar Names:
#  - damnation (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - damnation (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: assault suit leynos
# Similar Names:
#  - assault suit leynos (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - assault suit leynos (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: carmageddon: max damage
# Similar Names:
#  - carmageddon: max damage (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - carmageddon: max damage (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: metal gear solid v: the phantom pain
# Similar Names:
#  - metal gear solid v: the phantom pain (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - metal gear solid v: the phantom pain (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: just cause 3
# Similar Names:
#  - just cause™ 3 (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: anno 2205™
# Similar Names:
#  - anno 2205 (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: binary domain
# Similar Names:
#  - binary domain (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#  - binary domain (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: lego marvel's avengers
# Similar Names:
#  - lego® marvel's avengers (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: wolfenstein: the new order
# Similar Names:
#  - wolfenstein: the new order (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - wolfenstein: the new order (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: frontlines™: fuel of war™
# Similar Names:
#  - frontlines: fuel of war (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: worms: ultimate mayhem
# Similar Names:
#  - worms ultimate mayhem (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: call of juarez
# Similar Names:
#  - call of juarez™ (Year: 2007, Source: Steam, Similarity: 1.00)
#
# Base Name: frontlines: fuel of war
# Similar Names:
#  - frontlines™: fuel of war™ (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy’s splinter cell blacklist
# Similar Names:
#  - tom clancy's splinter cell: blacklist (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: left 4 dead 2
# Similar Names:
#  - left 4 dead 2 (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - left 4 dead 2 (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: [prototype 2]
# Similar Names:
#  - prototype 2 (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: lost horizon
# Similar Names:
#  - lost horizon (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - lost horizon (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: trials fusion™
# Similar Names:
#  - trials fusion (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: zero escape: zero time dilemma
# Similar Names:
#  - zero escape: zero time dilemma (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - zero escape: zero time dilemma (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: dead rising
# Similar Names:
#  - dead rising® (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: east india company
# Similar Names:
#  - east india company (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - east india company (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: grand ages: medieval
# Similar Names:
#  - grand ages: medieval (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - grand ages: medieval (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: the witcher® 3: wild hunt
# Similar Names:
#  - the witcher 3: wild hunt (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty: world at war
# Similar Names:
#  - call of duty: world at war (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#  - call of duty: world at war (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: agatha christie: the abc murders
# Similar Names:
#  - agatha christie - the abc murders (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: warhammer ,000: space marine
# Similar Names:
#  - warhammer ,000: space marine (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - warhammer ,000: space marine (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: braid
# Similar Names:
#  - braid (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - braid (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: metal gear solid v: ground zeroes
# Similar Names:
#  - metal gear solid v: ground zeroes (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - metal gear solid v: ground zeroes (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: valentino rossi: the game
# Similar Names:
#  - valentino rossi the game (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: spore galactic adventures
# Similar Names:
#  - spore™ galactic adventures (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: street fighter iv
# Similar Names:
#  - street fighter® iv (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: toukiden: kiwami
# Similar Names:
#  - toukiden kiwami (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: bladestorm: nightmare
# Similar Names:
#  - bladestorm: nightmare (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
# ...
#
# Base Name: order of war™
# Similar Names:
#  - order of war (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dragon age: origins - ultimate edition
# Similar Names:
#  - dragon age: origins - ultimate edition (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - dragon age: origins - ultimate edition (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: ship simulator extremes
# Similar Names:
#  - ship simulator extremes (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#  - ship simulator extremes (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: the night of the rabbit
# Similar Names:
#  - the night of the rabbit (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#  - the night of the rabbit (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: batman™: arkham knight
# Similar Names:
#  - batman: arkham knight (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: puzzler world 2
# Similar Names:
#  - puzzler world (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: flatout 2
# Similar Names:
#  - flatout 2™ (Year: 2006, Source: Steam, Similarity: 1.00)
#
# Base Name: trials fusion
# Similar Names:
#  - trials fusion™ (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: red faction®: armageddon™
# Similar Names:
#  - red faction: armageddon (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty®: modern warfare® 2
# Similar Names:
#  - call of duty: modern warfare 2 (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: battleborn
# Similar Names:
#  - battleborn (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - battleborn (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: haunted house™
# Similar Names:
#  - haunted house (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lego star wars iii: the clone wars
# Similar Names:
#  - lego® star wars™ iii - the clone wars™ (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: a game of thrones: genesis
# Similar Names:
#  - a game of thrones - genesis (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: ridge racer unbounded
# Similar Names:
#  - ridge racer™ unbounded (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: bejeweled 3
# Similar Names:
#  - bejeweled® 3 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: sid meier's civilization v
# Similar Names:
#  - sid meier's civilization® v (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: lego® star wars™ iii - the clone wars™
# Similar Names:
#  - lego star wars iii: the clone wars (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: blood bowl: legendary edition
# Similar Names:
#  - blood bowl - legendary edition (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: agatha christie - the abc murders
# Similar Names:
#  - agatha christie's the abc murders (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#  - agatha christie: the abc murders (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: tom clancy's the division
# Similar Names:
#  - tom clancy’s the division™ (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: one piece pirate warriors 3
# Similar Names:
#  - one piece: pirate warriors 3 (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lego batman 3: beyond gotham
# Similar Names:
#  - lego® batman™ 3: beyond gotham (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: the club
# Similar Names:
#  - the club™ (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: kingdoms of amalur: reckoning™
# Similar Names:
#  - kingdoms of amalur: reckoning (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty 3
# Similar Names:
#  - call of duty® (Year: 2006, Source: Steam, Similarity: 1.00)
#  - call of duty® 2 (Year: 2006, Source: Steam, Similarity: 1.00)
#
# Base Name: peggle nights
# Similar Names:
#  - peggle™ nights (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: rugby league team manager
# Similar Names:
#  - rugby league team manager (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - rugby league team manager (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: sniper elite 3
# Similar Names:
#  - sniper elite 3 (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#  - sniper elite 3 (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: prince of persia
# Similar Names:
#  - prince of persia® (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: f.e.a.r. 2: project origin
# Similar Names:
#  - f.e.a.r. 2: project origin (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#  - f.e.a.r. 2: project origin (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: dark souls™ iii
# Similar Names:
#  - dark souls iii (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: counter-strike: source
# Similar Names:
#  - counter-strike: source (Year: 2004.0, Source: VG_Sales, Similarity: 1.00)
#  - counter-strike: source (Year: 2004, Source: Steam, Similarity: 1.00)
#
# Base Name: might & magic x - legacy
# Similar Names:
#  - might & magic x: legacy (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: battlestations: pacific
# Similar Names:
#  - battlestations pacific (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: wolfenstein: the old blood
# Similar Names:
#  - wolfenstein: the old blood (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#  - wolfenstein: the old blood (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: rift
# Similar Names:
#  - rift (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - rift (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: wrc 5: fia world rally championship
# Similar Names:
#  - wrc 5 fia world rally championship (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: the sims 3
# Similar Names:
#  - the sims™ 3 (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: red faction: armageddon
# Similar Names:
#  - red faction®: armageddon™ (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: star wars™: the clone wars - republic heroes™
# Similar Names:
#  - star wars the clone wars: republic heroes (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: codename: panzers - cold war
# Similar Names:
#  - codename: panzers cold war (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dungeons - the dark lord
# Similar Names:
#  - dungeons - the dark lord (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#  - dungeons - the dark lord (Year: 2011, Source: Steam, Similarity: 1.00)
#
# Base Name: lego® batman™ 3: beyond gotham
# Similar Names:
#  - lego batman 3: beyond gotham (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: prototype 2
# Similar Names:
#  - [prototype 2] (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lego jurassic world
# Similar Names:
#  - lego® jurassic world (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: f1 race stars
# Similar Names:
#  - f1 race stars™ (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: puzzler world
# Similar Names:
#  - puzzler world 2 (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: medal of honor
# Similar Names:
#  - medal of honor™ (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: assassin’s creed® brotherhood
# Similar Names:
#  - assassin's creed: brotherhood (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: joint operations: combined arms
# Similar Names:
#  - joint operations: combined arms gold (Year: 2009, Source: Steam, Similarity: 0.93)
#
# Base Name: south park™: the stick of truth™
# Similar Names:
#  - south park: the stick of truth (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: trackmania turbo
# Similar Names:
#  - trackmania® turbo (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: silent hunter 5: battle of the atlantic
# Similar Names:
#  - silent hunter 5®: battle of the atlantic (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: thief
# Similar Names:
#  - thief () (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dark souls iii
# Similar Names:
#  - dark souls™ iii (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: battlestations pacific
# Similar Names:
#  - battlestations: pacific (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: singularity
# Similar Names:
#  - singularity™ (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: demolition company gold edition
# Similar Names:
#  - demolition company: gold edition (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: haunted house
# Similar Names:
#  - haunted house™ (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: south park: the stick of truth
# Similar Names:
#  - south park™: the stick of truth™ (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: silent hunter 5®: battle of the atlantic
# Similar Names:
#  - silent hunter 5: battle of the atlantic (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: hitman: absolution™
# Similar Names:
#  - hitman: absolution (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: order of war
# Similar Names:
#  - order of war™ (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: lego® harry potter: years 5-7
# Similar Names:
#  - lego harry potter: years 5-7 (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: anima gate of memories
# Similar Names:
#  - anima - gate of memories (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: crysis: warhead
# Similar Names:
#  - crysis warhead® (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: sid meier's civilization: beyond earth
# Similar Names:
#  - sid meier's civilization®: beyond earth™ (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: lords of the fallen
# Similar Names:
#  - lords of the fallen™ (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: star wars™: the force unleashed™ ii
# Similar Names:
#  - star wars: the force unleashed ii (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: might & magic heroes vii
# Similar Names:
#  - might & magic® heroes® vii (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: anima - gate of memories
# Similar Names:
#  - anima gate of memories (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's rainbow six® vegas 2
# Similar Names:
#  - tom clancy's rainbow six: vegas 2 (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: a game of thrones - genesis
# Similar Names:
#  - a game of thrones: genesis (Year: 2011.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: [prototype]
# Similar Names:
#  - prototype™ (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: might & magic® heroes® vii
# Similar Names:
#  - might & magic heroes vii (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: assassin's creed® syndicate
# Similar Names:
#  - assassin's creed syndicate (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: prototype™
# Similar Names:
#  - [prototype] (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dead rising 2
# Similar Names:
#  - dead rising® 2 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: homefront: the revolution
# Similar Names:
#  - homefront®: the revolution (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: spore™
# Similar Names:
#  - spore (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: rollercoaster tycoon world™
# Similar Names:
#  - rollercoaster tycoon world (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: dark souls ii
# Similar Names:
#  - dark souls™ ii (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's rainbow six® vegas
# Similar Names:
#  - tom clancy's rainbow six: vegas 2 (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: assassin's creed: unity
# Similar Names:
#  - assassin's creed® unity (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: lego star wars: the force awakens
# Similar Names:
#  - lego® star wars™: the force awakens (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: just cause™ 3
# Similar Names:
#  - just cause 3 (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty®
# Similar Names:
#  - call of duty 3 (Year: 2006.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lost planet 3
# Similar Names:
#  - lost planet® 3 (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: doom
# Similar Names:
#  - doom () (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty 4: modern warfare
# Similar Names:
#  - call of duty® 4: modern warfare® (Year: 2007, Source: Steam, Similarity: 1.00)
#
# Base Name: the crew™
# Similar Names:
#  - the crew (Year: 2014.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lost planet 2
# Similar Names:
#  - lost planet® 2 (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: risen 3: titan lords
# Similar Names:
#  - risen 3 - titan lords (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: far cry 4
# Similar Names:
#  - far cry® 4 (Year: 2014, Source: Steam, Similarity: 1.00)
#
# Base Name: mad max ()
# Similar Names:
#  - mad max (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: aliens vs. predator™
# Similar Names:
#  - aliens vs predator (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lego marvel super heroes
# Similar Names:
#  - lego® marvel™ super heroes (Year: 2013, Source: Steam, Similarity: 1.00)
#
# Base Name: trackmania® turbo
# Similar Names:
#  - trackmania turbo (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: kane and lynch: dead men™
# Similar Names:
#  - kane & lynch: dead men (Year: 2007.0, Source: VG_Sales, Similarity: 0.95)
#
# Base Name: codename: panzers cold war
# Similar Names:
#  - codename: panzers - cold war (Year: 2009, Source: Steam, Similarity: 1.00)
#
# Base Name: lego® jurassic world
# Similar Names:
#  - lego jurassic world (Year: 2015.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: call of duty® 2
# Similar Names:
#  - call of duty 3 (Year: 2006.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: batman™: arkham origins
# Similar Names:
#  - batman: arkham origins (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: lego® star wars™: the force awakens
# Similar Names:
#  - lego star wars: the force awakens (Year: 2016.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: men of war™
# Similar Names:
#  - men of war (Year: 2009.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: warhammer® ,000: dawn of war® - soulstorm
# Similar Names:
#  - warhammer ,000: dawn of war: soulstorm (Year: 2008.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: warhammer ,000: dawn of war: soulstorm
# Similar Names:
#  - warhammer® ,000: dawn of war® - soulstorm (Year: 2008, Source: Steam, Similarity: 1.00)
#
# Base Name: call of duty: black ops
# Similar Names:
#  - call of duty®: black ops (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: f1 ™
# Similar Names:
#  - f1 (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: sherlock holmes: crimes & punishments
# Similar Names:
#  - sherlock holmes: crimes and punishments (Year: 2014, Source: Steam, Similarity: 0.96)
#
# Base Name: far cry: primal
# Similar Names:
#  - far cry® primal (Year: 2016, Source: Steam, Similarity: 1.00)
#
# Base Name: damage inc.: pacific squadron wwii
# Similar Names:
#  - damage inc. pacific squadron wwii (Year: 2012, Source: Steam, Similarity: 1.00)
#
# Base Name: tom clancy's rainbow six: siege
# Similar Names:
#  - tom clancy's rainbow six® siege (Year: 2015, Source: Steam, Similarity: 1.00)
#
# Base Name: warhammer ,000: dawn of war ii - chaos rising
# Similar Names:
#  - warhammer® ,000: dawn of war® ii chaos rising (Year: 2010, Source: Steam, Similarity: 1.00)
#
# Base Name: call of duty®: black ops ii
# Similar Names:
#  - call of duty: black ops ii (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: warhammer® ,000: dawn of war® ii chaos rising
# Similar Names:
#  - warhammer ,000: dawn of war ii - chaos rising (Year: 2010.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: tomb raider
# Similar Names:
#  - tomb raider () (Year: 2013.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: damage inc. pacific squadron wwii
# Similar Names:
#  - damage inc.: pacific squadron wwii (Year: 2012.0, Source: VG_Sales, Similarity: 1.00)
#
# Base Name: flatout 2™
# Similar Names:
#  - flatout 2 (Year: 2006.0, Source: VG_Sales, Similarity: 1.00)
